# %%
#functions needed 
# computing words within 2 edit distance of a word 
# given a sentence compute the probability of the sentence using bi-gram modelling

# %%
# non-word errors 

# (1) Find the error word by comparing each word with the dictionary 
# (2) Compute the possible replacement of the word by the edit distance metric 
# (3) Rank the candidates using probability of edit distance 
# (3) For the top k words, find the sentence probability. 
# (4) Select the best sentence and proceed.

# %%
import nltk

# %%
nltk.download('gutenberg')
nltk.download('wordnet')
nltk.download('wordnet_ic')
nltk.download('omw-1.4')
nltk.download('punkt')
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]   Package wordnet_ic is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
files = nltk.corpus.gutenberg.fileids()
print(files)
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']

# %%
from nltk.corpus import gutenberg

# %%
emma_words = gutenberg.words('austen-emma.txt')
len(emma_words)
# Out:
# 192427

# %%
# (1) Preprocess all the sentences to create vocabulary 

# Stemming 
# lemmatization 
# remove numbers 
# lowercase 
# remove punctuation 
# remove stopwords

from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer 
import re

stopwords = set(nltk.corpus.stopwords.words('english'))
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()


def preprocess_sentence(text):

  text = text.lower()
 
  text = re.sub(r'[^\w\s]', '', text)

  text = re.sub(r'[0-9]', '', text)

  #remove unwanted spaces
  text = re.sub(' +', ' ', text)

  #remove trailing spaces 
  text = text.strip()

  #remove stop words
  f = [w for w in text.split(" ") if w not in stopwords]

  text = " ".join(f)

  # text = text.split(" ")
  # text = [stemmer.stem(word) for word in text]
  # text = [lemmatizer.lemmatize(word) for word in text]
  return text

# %%
emma = nltk.corpus.gutenberg.sents('austen-emma.txt')
print(emma)
# Out:
# [['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']'], ['VOLUME', 'I'], ...]

# %%
#create vocab
vocab = {}

for sentence in emma:

  res = preprocess_sentence(" ".join(sentence))

  for word in res.split(" "):
    if word in vocab:
      vocab[word] += 1
    else:
      vocab[word] = 1

# %%
#return all words in the vocabulary that lie within edit distance 2 of the given word

def edit_distance1(word):

    l   = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in l]
    inserts    = [L + c + R               for L, R in splits for c in l]
    return set(deletes + transposes + replaces + inserts)

def edit_distance2(word): 
    return (e2 for e1 in edit_distance1(word) for e2 in edit_distance1(e1))

def candidate_words(word, vocab):

  a1 = list(edit_distance1(word))
  a2 = list(edit_distance2(word))

  s1 = set(vocab.keys())
  s2 = set(a1 + a2)

  return list(s1.intersection(s2))

# %%
def editDistDP(str1, str2, m, n):
    dp = [[0 for x in range(n + 1)] for x in range(m + 1)]
 
    for i in range(m + 1):
        for j in range(n + 1):

            if i == 0:
                dp[i][j] = j  
 
            elif j == 0:
                dp[i][j] = i   

            elif str1[i-1] == str2[j-1]:
                dp[i][j] = dp[i-1][j-1]

            else:
                dp[i][j] = 1 + min(dp[i][j-1],        
                                   dp[i-1][j],        
                                   dp[i-1][j-1])    
 
    return dp[m][n]

# %%
# function to return top k candidate words

def top_k(incorrect_word,vocab,k):

  def sort_f(correct_word):

    val = editDistDP(incorrect_word, correct_word, len(incorrect_word), len(correct_word))
    return val

  cws = candidate_words(incorrect_word, vocab)
  cws.sort(key = sort_f)

  return cws if k > len(cws) else cws[:k]

# %%
top_k("acress", vocab, 3)
# Out:
# ['across', 'agrees', 'aches']

# %%
#prepare train and test corpus 
emma = nltk.corpus.gutenberg.sents('austen-emma.txt')

from sklearn.model_selection import train_test_split

train, test = train_test_split(emma, test_size=0.2, random_state=23)

# %%
train_processed = [preprocess_sentence(" ".join(s)) for s in train]
train_processed[2]
# Out:
# '_you_ probably less surprized us suspicions forgotten tried give caution wish attended sinking voice heavy sigh seem doomed blindness'

# %%
# train bigram model and calculate sentence probability 

import itertools

class Bigram:

  def __init__(self, train_corpus):
    self.tc = train_corpus
    self.prob = self.train_bigram()

  def pairwise(self,iterable):
      "s -> (s0, s1), (s1, s2), (s2, s3), ..."
      a, b = itertools.tee(iterable)
      next(b, None)
      return zip(a, b)  

  def train_bigram(self):

    #unigram dict
    unigrams = {}
    prob = {}
    for sentence in self.tc:

      for word in sentence.split(" "):
        if word in unigrams:
          unigrams[word] += 1
        else:
          unigrams[word] = 1
      
    for word in unigrams:
      prob[word] = unigrams[word] / sum(unigrams.values())

    #bigrams dict 

    bigrams = {}
    for sentence in train_processed:

      for pair in self.pairwise(sentence.split(" ")):

        if pair in bigrams:
          bigrams[pair] += 1
        else:
          bigrams[pair] = 1

    for pair in bigrams:
      prob[pair] = bigrams[pair] / unigrams[pair[0]]

    return prob

  def sentence_prob(self, sentence):

    #prob is the probability dictionary which is the result of training

    sentence = preprocess_sentence(sentence)
    p = 1
    split_s = sentence.split(" ")

    if split_s[0] not in self.prob:
      p *= pow(10, -4)
    else:
      p *= self.prob[split_s[0]]

    if split_s[-1] not in self.prob:
      p *= pow(10, -4)
    else:
      p *= self.prob[split_s[-1]]
    
    for pair in self.pairwise(sentence.split(" ")):

      if pair not in self.prob:
        p *= pow(10,-6)
      else:
        p *= self.prob[pair]

    return p

# %%
train_processed[1]
# Out:
# 'doubt whether sense would corrected without'

# %%
bigram = Bigram(train_processed)

# %%
def correct_sentence(sentence,vocab):

  split_s = sentence.split(" ")

  for word in split_s:
    if word not in vocab:
      #this is the incorrect word
      cws = top_k(word, vocab, 5)
      ic = word
      break
  
  candidate_sentences = [sentence.replace(word, cw) for cw in cws]

  candidate_sentences.sort(reverse = True, key = bigram.sentence_prob)

  return candidate_sentences

# %%
correct_sentence("i doubt wether my own sense would have corrected me without it", vocab)
# Out:
# [' doubt wether my own sense would have corrected me wthout t',
#  'e doubt wether my own sense would have corrected me wethout et',
#  'k doubt wether my own sense would have corrected me wkthout kt',
#  'c doubt wether my own sense would have corrected me wcthout ct',
#  'ix doubt wether my own sense would have corrected me wixthout ixt']

# %%
test_processed = [preprocess_sentence(" ".join(s)) for s in test]
test_processed[2]
# Out:
# 'understood delayed till colonel campbell return'

# %%
correct_sentence("understood delayed till colonel campbell retun", vocab)
# Out:
# ['understood delayed till colonel campbell return',
#  'understood delayed till colonel campbell begun',
#  'understood delayed till colonel campbell reign',
#  'understood delayed till colonel campbell recur',
#  'understood delayed till colonel campbell retain']

# %% [markdown]
# ##ACCURACY Non-Word Errors

# %%
import random 

def accuracy_nonword(test_corpus, vocab):

  correct = 0

  tp = [preprocess_sentence(" ".join(s)) for s in test_corpus]
  
  for sentence in tp:
    #randomly choose a word and modify within 2 edit distance such that it does not lie in the vocabulary 

    split_s = sentence.split(" ")
    random_index = random.randint(0, len(split_s)-1)

    word = split_s[random_index]

    possible_words = set(list(edit_distance1(word)) + list(edit_distance2(word)))
    final_pw = list(possible_words.difference(set(vocab.keys())))

    incorrect_s = sentence.replace(word, final_pw[0])

    output_model = correct_sentence(incorrect_s, vocab)

    if not output_model:
      continue

    print("Original sentence: ", sentence)
    print("Mistyped non-word error sentence: ", incorrect_s)
    print("Model Output: ", output_model[0])
    print("\n")

    if output_model[0] == sentence:
      correct +=1

  return correct / len(tp)

# %%
#testing accuracy on a subset of test set

print("The accuracy is:", accuracy_nonword(test,vocab) * 100)
# Out:
# Streaming output truncated to the last 5000 lines.
# Mistyped non-word error sentence:  surprized jane vfamirfax accepts civilities consents
# Model Output:  surprized jane fairfax accepts civilities consents
#
#
# Original sentence:  oh
# Mistyped non-word error sentence:  vol
# Model Output:  told
#
#
# Original sentence:  extent admiration may take surprize day
# Mistyped non-word error sentence:  txvent admiration may take surprize day
# Model Output:  extent admiration may take surprize day
#
#
# Original sentence:  hope retract said
# Mistyped non-word error sentence:  hope retract saee
# Model Output:  hope retract see
#
#
# Original sentence:  owned considering every thing absolutely without inclination party
# Mistyped non-word error sentence:  owned considering every thing absolutely witsoiut inclination party
# Model Output:  owned considering every thing absolutely without inclination party
#
#
# Original sentence:  gave understand frank admired extremely thought beautiful charming much said altogether found must judge harshly
# Mistyped non-word error sentence:  gave junderpstand frank admired extremely thought beautiful charming much said altogether found must judge harshly
# Model Output:  gave understand frank admired extremely thought beautiful charming much said altogether found must judge harshly
#
#
# Original sentence:  better order carriage directly love said dare say shall able get along set directly come thing bad get walk
# Mistyped non-word error sentence:  better ordhecr carriage directly love said dare say shall able get along set directly come thing bad get walk
# Model Output:  better order carriage directly love said dare say shall able get along set directly come thing bad get walk
#
#
# Original sentence:  friend knightley often mentioned really impatient see must caro sposo justice say need ashamed friend
# Mistyped non-word error sentence:  friend knightley often mentioned really impatient scoe must caro sposo justice say need ashamed friend
# Model Output:  friend knightley often mentioned really impatient soon must caro sposo justice say need ashamed friend
#
#
# Original sentence:  emma thinking moment made information received valuable
# Mistyped non-word error sentence:  emma thinking moment saee information received valuable
# Model Output:  emma thinking moment sake information received valuable
#
#
# Original sentence:  first error worst lay door
# Mistyped non-word error sentence:  first error wobrost lay door
# Model Output:  first error worst lay door
#
#
# Original sentence:  recollect clever way
# Mistyped non-word error sentence:  recollect dlgever way
# Model Output:  recollect clever way
#
#
# Original sentence:  wrong know keep remembrances married
# Mistyped non-word error sentence:  wrong know kdip remembrances married
# Model Output:  wrong know lip remembrances married
#
#
# Original sentence:  believed share feelings would wretched
# Mistyped non-word error sentence:  believed share feelings wovod wretched
# Model Output:  believed share feelings wood wretched
#
#
# Original sentence:  ever might feel brighter hope betrayed nothing
# Mistyped non-word error sentence:  dvar might feel brighter hope betrayed nothing
# Model Output:  dear might feel brighter hope betrayed nothing
#
#
# Original sentence:  turning mr knightley know seldom ever two hours hartfield foresee series dissipation cannot imagine
# Mistyped non-word error sentence:  turning mr knightley rqow seldom ever two hours hartfield foresee series dissipation cannot imagine
# Model Output:  turning mr knightley row seldom ever two hours hartfield foresee series dissipation cannot imagine
#
#
# Original sentence:  obliged go evening call duty business hardship deem probably rather thinner clothing usual setting forward voluntarily without excuse defiance voice nature tells man every thing given view feelings stay home keep shelter setting forward spend five dull hours another man house nothing say hear said heard yesterday may said heard morrow
# Mistyped non-word error sentence:  obliged go evening call duty business hardship deem probably rather thinner clothing usual setting forward voluntarily without excuse defiance voice nature tells man every thing given view feelings stay home keep shelter setting forward spend five iduml hours another man house nothing say hear said heard yesterday may said heard morrow
# Model Output:  obliged go evening call duty business hardship deem probably rather thinner clothing usual setting forward voluntarily without excuse defiance voice nature tells man every thing given view feelings stay home keep shelter setting forward spend five dull hours another man house nothing say hear said heard yesterday may said heard morrow
#
#
# Original sentence:  see
# Mistyped non-word error sentence:  scoe
# Model Output:  soon
#
#
# Original sentence:  poverty certainly contracted mind really believe shilling world would likely give away sixpence nobody afraid great charm
# Mistyped non-word error sentence:  poverty certainly conrractexd mind really believe shilling world would likely give away sixpence nobody afraid great charm
# Model Output:  poverty certainly contracted mind really believe shilling world would likely give away sixpence nobody afraid great charm
#
#
# Original sentence:  well done mrs
# Mistyped non-word error sentence:  well done mxsa
# Model Output:  well done miss
#
#
# Original sentence:  mention names happy man changes emma harriet
# Mistyped non-word error sentence:  melnvtion names happy man changes emma harriet
# Model Output:  mention names happy man changes emma harriet
#
#
# Original sentence:  never saw thing hard
# Mistyped non-word error sentence:  never smxaw thing hard
# Model Output:  never saw thing hard
#
#
# Original sentence:  john loves emma reasonable therefore blind affection isabella always thinks except quite frightened enough children
# Mistyped non-word error sentence:  jkoha loves emma reasonable therefore blind affection isabella always thinks except quite frightened enough children
# Model Output:  john loves emma reasonable therefore blind affection isabella always thinks except quite frightened enough children
#
#
# Original sentence:  must given
# Mistyped non-word error sentence:  must gmivezn
# Model Output:  must given
#
#
# Original sentence:  _her_ connexions may worse _his_
# Mistyped non-word error sentence:  _her_ connexions may aworase _his_
# Model Output:  _her_ connexions may worse _his_
#
#
# Original sentence:  pray take care mrs weston step turning
# Mistyped non-word error sentence:  pray take care mrs wenjton step turning
# Model Output:  pray take care mrs weston step turning
#
#
# Original sentence:  soon flies present failure begins hope
# Mistyped non-word error sentence:  soon flidsr present failure begins hope
# Model Output:  soon flies present failure begins hope
#
#
# Original sentence:  drawings always dear
# Mistyped non-word error sentence:  dreyings always dear
# Model Output:  drawings always dear
#
#
# Original sentence:  goldsmith tells us lovely woman stoops folly nothing die stoops disagreeable equally recommended clearer ill fame
# Mistyped non-word error sentence:  goldsmith tells us lovely woman sattoops folly nothing die sattoops disagreeable equally recommended clearer ill fame
# Model Output:  goldsmith tells us lovely woman stoops folly nothing die stoops disagreeable equally recommended clearer ill fame
#
#
# Original sentence:  dear sir upon account world father direct
# Mistyped non-word error sentence:  gearp sir upon account world father direct
# Model Output:  fears sir upon account world father direct
#
#
# Original sentence:  cried emma feelingly
# Mistyped non-word error sentence:  cried emmve feelingly
# Model Output:  cried emma feelingly
#
#
# Original sentence:  heart
# Mistyped non-word error sentence:  gearp
# Model Output:  heard
#
#
# Original sentence:  emma said paper worse expected
# Mistyped non-word error sentence:  emma said paper aworase expected
# Model Output:  emma said paper worse expected
#
#
# Original sentence:  frank standing steadily restlessness shewed mind ease
# Mistyped non-word error sentence:  frank standing steadily resztlepssness shewed mind ease
# Model Output:  frank standing steadily restlessness shewed mind ease
#
#
# Original sentence:  observed mrs elton course life things going untowardly one month sure mend next
# Mistyped non-word error sentence:  observed mrs elton course life thancs going untowardly one month sure mend next
# Model Output:  observed mrs elton course life thanks going untowardly one month sure mend next
#
#
# Original sentence:  happy hear jane fairfax one knows accomplished superior exactly emma age
# Mistyped non-word error sentence:  happy hear jane fairfax one knows accomplished fsuperixr exactly emma age
# Model Output:  happy hear jane fairfax one knows accomplished superior exactly emma age
#
#
# Original sentence:  ah
# Mistyped non-word error sentence:  aeth
# Model Output:  met
#
#
# Original sentence:  honestly said much mr e speaking future home expressing fears lest retirement disagreeable inferiority house knowing accustomed course wholly without apprehension
# Mistyped non-word error sentence:  honestly said much mr e speaking future home expressing gearp lest retirement disagreeable inferiority house knowing accustomed course wholly without apprehension
# Model Output:  honestly said much mr e speaking future home expressing heard lest retirement disagreeable inferiority house knowing accustomed course wholly without apprehension
#
#
# Original sentence:  glad made play much instrument grandmother must real indulgence
# Mistyped non-word error sentence:  glad made play much instrument grandmother must fxeal indulgence
# Model Output:  glad made play much instrument grandmother must feel indulgence
#
#
# Original sentence:  mrs weston friends made happy safety satisfaction well could increased emma knowing mother little girl
# Mistyped non-word error sentence:  mrs weston friends made happy safety satisfaction well could increased emma knowing mother little oghirl
# Model Output:  mrs weston friends made happy safety satisfaction well could increased emma knowing mother little girl
#
#
# Original sentence:  gone three miles round one day order bring walnuts said fond every thing else obliging
# Mistyped non-word error sentence:  gone three miles round one day order bring walnuts said fjonpd every thing else obliging
# Model Output:  gone three miles round one day order bring walnuts said fond every thing else obliging
#
#
# Original sentence:  impossible never call thing mr
# Mistyped non-word error sentence:  impossible never cphll thing mr
# Model Output:  impossible never call thing mr
#
#
# Original sentence:  made tall emma said mr knightley
# Mistyped non-word error sentence:  made tall emma saee mr knightley
# Model Output:  made tall emma safe mr knightley
#
#
# Original sentence:  shall leave well
# Mistyped non-word error sentence:  shall leave twelc
# Model Output:  shall leave well
#
#
# Original sentence:  one cannot large party
# Mistyped non-word error sentence:  one cannot large mpartyq
# Model Output:  one cannot large party
#
#
# Original sentence:  certainly persuade feel
# Mistyped non-word error sentence:  certainly persuade fgfl
# Model Output:  certainly persuade feel
#
#
# Original sentence:  thing attentive
# Mistyped non-word error sentence:  thing attentnivy
# Model Output:  thing attentive
#
#
# Original sentence:  say quite invalid go therefore must decline obliging invitation beginning _compliments_ course
# Mistyped non-word error sentence:  say quite dnvalwid go therefore must decline obliging invitation beginning _compliments_ course
# Model Output:  say quite invalid go therefore must decline obliging invitation beginning _compliments_ course
#
#
# Original sentence:  dining coles ball talked never took place
# Mistyped non-word error sentence:  dining koler ball talked never took place
# Model Output:  dining lower ball talked never took place
#
#
# Original sentence:  consider partial quarter information came
# Mistyped non-word error sentence:  consider partial fquaraer information came
# Model Output:  consider partial quarter information came
#
#
# Original sentence:  manner perhaps may little recommend
# Mistyped non-word error sentence:  kmanoer perhaps may little recommend
# Model Output:  manner perhaps may little recommend
#
#
# Original sentence:  perhaps ought ashamed mr weston almost uneasy ten minutes however child perfectly well
# Mistyped non-word error sentence:  perhaps ought ashamed mrqg weston almost uneasy ten minutes however child perfectly well
# Model Output:  perhaps ought ashamed mrs weston almost uneasy ten minutes however child perfectly well
#
#
# Original sentence:  elton
# Mistyped non-word error sentence:  ueliton
# Model Output:  elton
#
#
# Original sentence:  know time
# Mistyped non-word error sentence:  rqow time
# Model Output:  snow time
#
#
# Original sentence:  young uncle perhaps
# Mistyped non-word error sentence:  yzzng uncle perhaps
# Model Output:  young uncle perhaps
#
#
# Original sentence:  forget take friend message miss smith shall happy deliver _me_ please
# Mistyped non-word error sentence:  forget take friend message miss smith shall happy deliver eme_a please
# Model Output:  forget take friend message miss smith shall happy deliver emma please
#
#
# Original sentence:  minutes entire silence john knightley began
# Mistyped non-word error sentence:  mizute entire silence john knightley began
# Model Output:  minutes entire silence john knightley began
#
#
# Original sentence:  avowedly due _her_
# Mistyped non-word error sentence:  aouvwedly due _her_
# Model Output:  avowedly due _her_
#
#
# Original sentence:  went however
# Mistyped non-word error sentence:  went hodweqver
# Model Output:  went however
#
#
# Original sentence:  seemed like cheerful easy friends lovers
# Mistyped non-word error sentence:  vremed like cheerful easy friends lovers
# Model Output:  seemed like cheerful easy friends lovers
#
#
# Original sentence:  think would much better would come one afternoon next summer take tea us take us afternoon walk might hours reasonable yet get home without damp evening
# Mistyped non-word error sentence:  think would much bettjel would come one afternoon next summer take tea us take us afternoon walk might hours reasonable yet get home without damp evening
# Model Output:  think would much better would come one afternoon next summer take tea us take us afternoon walk might hours reasonable yet get home without damp evening
#
#
# Original sentence:  bring new proposal subject thought father waits approbation acted upon
# Mistyped non-word error sentence:  bring new proposal suobnject thought father waits approbation acted upon
# Model Output:  bring new proposal subject thought father waits approbation acted upon
#
#
# Original sentence:  meant immediately mixed others buried sight looked table instead looking across mixed harriet eager every fresh word finding none directly took fell work
# Mistyped non-word error sentence:  meant immediately mixed others buried sight looked table instead looking across mixed harriet eager every fresh word finding nunet directly took fell work
# Model Output:  meant immediately mixed others buried sight looked table instead looking across mixed harriet eager every fresh word finding nine directly took fell work
#
#
# Original sentence:  pain obliged practise concealment towards little inferior pain made harriet unhappy
# Mistyped non-word error sentence:  pain obliged practise concealment towards little inferior pain saee harriet unhappy
# Model Output:  pain obliged practise concealment towards little inferior pain see harriet unhappy
#
#
# Original sentence:  entirely without think
# Mistyped non-word error sentence:  egxtirely without think
# Model Output:  entirely without think
#
#
# Original sentence:  try find miss woodhouse
# Mistyped non-word error sentence:  try find kmissx woodhouse
# Model Output:  try find miss woodhouse
#
#
# Original sentence:  dear harriet must refine much upon charade betray feelings improperly conscious quick appear affix meaning even quite meaning may affixed
# Mistyped non-word error sentence:  dear harriet must refine much upon charade betray feelings improperly conscious quick appear affix meaning even quite meaning ipay affixed
# Model Output:  dear harriet must refine much upon charade betray feelings improperly conscious quick appear affix meaning even quite meaning pay affixed
#
#
# Original sentence:  miss smith miss fairfax three two miss coxes five five couple plenty room
# Mistyped non-word error sentence:  miss smith miss fairfax thrcef two miss coxes five five couple plenty room
# Model Output:  miss smith miss fairfax three two miss coxes five five couple plenty room
#
#
# Original sentence:  excepting brother know equal temper
# Mistyped non-word error sentence:  excmptbing brother know equal temper
# Model Output:  excepting brother know equal temper
#
#
# Original sentence:  could change shoes know moment got home sort thing gives cold
# Mistyped non-word error sentence:  could change shoes know moment got home sort thing gives acolud
# Model Output:  could change shoes know moment got home sort thing gives could
#
#
# Original sentence:  told observe carefully let behaviour rule mine
# Mistyped non-word error sentence:  told osszerve carefully let behaviour rule mine
# Model Output:  told observe carefully let behaviour rule mine
#
#
# Original sentence:  june soon
# Mistyped non-word error sentence:  june gsloon
# Model Output:  june soon
#
#
# Original sentence:  keep horses moment
# Mistyped non-word error sentence:  keep horses momeuntf
# Model Output:  keep horses moment
#
#
# Original sentence:  may well say lot cast goodly heritage
# Mistyped non-word error sentence:  may well say lot cast goodly ierijtage
# Model Output:  may well say lot cast goodly heritage
#
#
# Original sentence:  _i_ sick prosperity indulgence
# Mistyped non-word error sentence:  _i_ sailck prosperity indulgence
# Model Output:  _i_ sick prosperity indulgence
#
#
# Original sentence:  emma good deal surprized begged speak
# Mistyped non-word error sentence:  emma good deamlx surprized begged speak
# Model Output:  emma good deal surprized begged speak
#
#
# Original sentence:  find making use word _sacrifice_ said one clever replies delicate negatives allusion making sacrifice
# Mistyped non-word error sentence:  find making ausei word _sacrifice_ said one clever replies delicate negatives allusion making sacrifice
# Model Output:  find making amuse word _sacrifice_ said one clever replies delicate negatives allusion making sacrifice
#
#
# Original sentence:  occasion marry either fill time heart
# Mistyped non-word error sentence:  occasion marry either fill time gearp
# Model Output:  occasion marry either fill time heard
#
#
# Original sentence:  know
# Mistyped non-word error sentence:  rqow
# Model Output:  snow
#
#
# Original sentence:  joy gratitude exquisite delight sensations may imagined
# Mistyped non-word error sentence:  joy gratiytuie exquisite delight sensations may imagined
# Model Output:  joy gratitude exquisite delight sensations may imagined
#
#
# Original sentence:  _miss_ _woodhouse_ appeared never without something pleasing connexion either compliment taste remembrance said last time meeting eye unadorned broad wreath gallantry yet could discern effect influence acknowledge greatest compliment perhaps conveyed
# Mistyped non-word error sentence:  _miss_ _woodhouse_ appeared never without something pleasing connexion either compliment taste remembrance said last time meeting eye unadorned broad wzreathg gallantry yet could discern effect influence acknowledge greatest compliment perhaps conveyed
# Model Output:  _miss_ _woodhouse_ appeared never without something pleasing connexion either compliment taste remembrance said last time meeting eye unadorned broad wreath gallantry yet could discern effect influence acknowledge greatest compliment perhaps conveyed
#
#
# Original sentence:  _we_ set example many follow far though situations
# Mistyped non-word error sentence:  _we_ set example many fololoa far though situations
# Model Output:  _we_ set example many follow far though situations
#
#
# Original sentence:  could enter house could room vain artifice retreated three months ago lace boot without _recollecting_
# Mistyped non-word error sentence:  could enter house could room vain artifice retreated three months gagco lace boot without _recollecting_
# Model Output:  could enter house could room vain artifice retreated three months ago lace boot without _recollecting_
#
#
# Original sentence:  emma infatuation girl blinds
# Mistyped non-word error sentence:  emma infatuytmon girl blinds
# Model Output:  emma infatuation girl blinds
#
#
# Original sentence:  yes quite proposal marriage good letter least thought
# Mistyped non-word error sentence:  yes quite proposal marriage good letter leasdts thought
# Model Output:  yes quite proposal marriage good letter least thought
#
#
# Original sentence:  got hannah good place
# Mistyped non-word error sentence:  got hannah good pklacp
# Model Output:  got hannah good place
#
#
# Original sentence:  nothing wrong escaped
# Mistyped non-word error sentence:  lnothiwng wrong escaped
# Model Output:  nothing wrong escaped
#
#
# Original sentence:  playing _robin_ _adair_ moment _his_ favourite
# Mistyped non-word error sentence:  playing _robin_ _adair_ momeuntf _his_ favourite
# Model Output:  playing _robin_ _adair_ moments _his_ favourite
#
#
# Original sentence:  places town offices inquiry would soon produce something offices sale quite human flesh human intellect
# Mistyped non-word error sentence:  places town offices inquiry would soon produce something offices sale quite hugans flesh hugans intellect
# Model Output:  places town offices inquiry would soon produce something offices sale quite human flesh human intellect
#
#
# Original sentence:  feared every body else must think predict
# Mistyped non-word error sentence:  feared every body else must thhnke predict
# Model Output:  feared every body else must think predict
#
#
# Original sentence:  emma extremely confused
# Mistyped non-word error sentence:  emma ectremelt confused
# Model Output:  emma extremely confused
#
#
# Original sentence:  mean return favourable answer collect
# Mistyped non-word error sentence:  mean return fpvourablze answer collect
# Model Output:  mean return favourable answer collect
#
#
# Original sentence:  oh
# Mistyped non-word error sentence:  vol
# Model Output:  told
#
#
# Original sentence:  regard receiving strength invariable praise regrets kept alive feelings irritated ceaseless repetitions miss hawkins happiness continual observation much seemed attached air walked house sitting hat proof much love
# Mistyped non-word error sentence:  regard receiving strength inwvaroable praise regrets kept alive feelings irritated ceaseless repetitions miss hawkins happiness continual observation much seemed attached air walked house sitting hat proof much love
# Model Output:  regard receiving strength invariable praise regrets kept alive feelings irritated ceaseless repetitions miss hawkins happiness continual observation much seemed attached air walked house sitting hat proof much love
#
#
# Original sentence:  dixon well
# Mistyped non-word error sentence:  dixon twelc
# Model Output:  dixon well
#
#
# Original sentence:  oh yes great difference
# Mistyped non-word error sentence:  vol yes great difference
# Model Output:  told yes great difference
#
#
# Original sentence:  sure opinions
# Mistyped non-word error sentence:  saee opinions
# Model Output:  see opinions
#
#
# Original sentence:  shews sad invalid
# Mistyped non-word error sentence:  sqetws sad invalid
# Model Output:  shews sad invalid
#
#
# Original sentence:  oh
# Mistyped non-word error sentence:  vol
# Model Output:  told
#
#
# Original sentence:  companion tells said absolutely promised miss bates last night would come morning
# Mistyped non-word error sentence:  companion tells said absolutely promised miss bates last night would come lonning
# Model Output:  companion tells said absolutely promised miss bates last night would come looking
#
#
# Original sentence:  extremely fond danger surely
# Mistyped non-word error sentence:  ectremelt fond danger surely
# Model Output:  extremely fond danger surely
#
#
# Original sentence:  call another day hear pianoforte
# Mistyped non-word error sentence:  call another day gearp pianoforte
# Model Output:  call another day heard pianoforte
#
#
# Original sentence:  article fully acquit
# Mistyped non-word error sentence:  articljke fully acquit
# Model Output:  article fully acquit
#
#
# Original sentence:  misery suffered concealment many months continued mrs weston energetic
# Mistyped non-word error sentence:  misery suffered concealment many months contisiued mrs weston energetic
# Model Output:  misery suffered concealment many months continued mrs weston energetic
#
#
# Original sentence:  well coming see good news think
# Mistyped non-word error sentence:  well coming see good nsewsy think
# Model Output:  well coming see good news think
#
#
# Original sentence:  striving look taller body else
# Mistyped non-word error sentence:  striving lowokk taller body else
# Model Output:  striving look taller body else
#
#
# Original sentence:  introducing good company giving opportunity pleasing one worth ought attempted
# Mistyped non-word error sentence:  introducing good compasnv giving opportunity pleasing one worth ought attempted
# Model Output:  introducing good company giving opportunity pleasing one worth ought attempted
#
#
# Original sentence:  idea mr knightley returning affection
# Mistyped non-word error sentence:  idea mr knightley returning adfuection
# Model Output:  idea mr knightley returning affection
#
#
# Original sentence:  weston judge us
# Mistyped non-word error sentence:  wenjton judge us
# Model Output:  weston judge us
#
#
# Original sentence:  mr frank churchill indeed
# Mistyped non-word error sentence:  mr frank churchill indrek
# Model Output:  mr frank churchill indeed
#
#
# Original sentence:  deficient nothing make amends
# Mistyped non-word error sentence:  deficient nothing make amefndt
# Model Output:  deficient nothing make amends
#
#
# Original sentence:  cheerful animated suspicious busy imaginations
# Mistyped non-word error sentence:  cheerful animated suspkciopus busy imaginations
# Model Output:  cheerful animated suspicious busy imaginations
#
#
# Original sentence:  mentioned _names_ observe oh
# Mistyped non-word error sentence:  mentioned _names_ observe vol
# Model Output:  mentioned _names_ observe told
#
#
# Original sentence:  excuse much powered
# Mistyped non-word error sentence:  hxcuxe much powered
# Model Output:  excuse much powered
#
#
# Original sentence:  owed risk thing might involved unwelcome interference rather welfare encounter thing rather remembrance neglect cause
# Mistyped non-word error sentence:  owed risk thing might involved unwelcome interference rather welfare encounter thing rather remembrance neglect sausek
# Model Output:  owed risk thing might involved unwelcome interference rather welfare encounter thing rather remembrance neglect cause
#
#
# Original sentence:  seen country afraid think overrated hartfield
# Mistyped non-word error sentence:  seen country afraid thhnke overrated hartfield
# Model Output:  seen country afraid thinks overrated hartfield
#
#
# Original sentence:  taken place year would grievance
# Mistyped non-word error sentence:  taken place year would grisvancde
# Model Output:  taken place year would grievance
#
#
# Original sentence:  always patience could wished
# Mistyped non-word error sentence:  aleayas patience could wished
# Model Output:  always patience could wished
#
#
# Original sentence:  hoped time
# Mistyped non-word error sentence:  hopehhd time
# Model Output:  hoped time
#
#
# Original sentence:  mr knightley always kind feeling truly considerate every body would never deserve less worshipped really much hope even harriet could love _three_ men one year
# Mistyped non-word error sentence:  mr knightley always kind feeling yrdly considerate every body would never deserve less worshipped really much hope even harriet could love _three_ men one year
# Model Output:  mr knightley always kind feeling dryly considerate every body would never deserve less worshipped really much hope even harriet could love _three_ men one year
#
#
# Original sentence:  tell letter dear said father
# Mistyped non-word error sentence:  tell lettxegr dear said father
# Model Output:  tell letter dear said father
#
#
# Original sentence:  taken pains sake robert martin sake always reason believe much love ever get acquainted
# Mistyped non-word error sentence:  taken pains sake robert martin sake always reason believe umunch love ever get acquainted
# Model Output:  taken pains sake robert martin sake always reason believe much love ever get acquainted
#
#
# Original sentence:  cried emma collecting resolutely let us understand without possibility farther mistake
# Mistyped non-word error sentence:  cried emma collecting resolutely let us understand witsoiut possibility farther mistake
# Model Output:  cried emma collecting resolutely let us understand without possibility farther mistake
#
#
# Original sentence:  dear affectionate creature _you_ banished abbey mill farm _you_ confined society illiterate vulgar life
# Mistyped non-word error sentence:  dear affectionate creature _you_ banished abbey mill farm _you_ confined society illiterate vutlqgar life
# Model Output:  dear affectionate creature _you_ banished abbey mill farm _you_ confined society illiterate vulgar life
#
#
# Original sentence:  felt honest pride complacency alliance present future proprietor could fairly warrant viewed respectable size style building suitable becoming characteristic situation low sheltered ample gardens stretching meadows washed stream abbey old neglect prospect scarcely sight abundance timber rows avenues neither fashion extravagance rooted house larger hartfield totally unlike covering good deal ground rambling irregular many comfortable one two handsome rooms ought looked emma felt increasing respect residence family true gentility untainted blood understanding faults temper john knightley isabella connected unexceptionably
# Mistyped non-word error sentence:  felt honest pride complacency alliance present future proprietor could fairly warrant viewed respectable size style building suitable becoming characteristic situation low sheltered ample gardens stretching meadows washed stream abbey old neglect prospect scarcely sight abundance timber rows avenues neither fashion extravagance rooted house larger hartfield totally unlike covering good deal ground rambling irregular many comfortable one two handsome rooms ought looked emma felt increasing respect residence family true gegntilmity untainted blood understanding faults temper john knightley isabella connected unexceptionably
# Model Output:  felt honest pride complacency alliance present future proprietor could fairly warrant viewed respectable size style building suitable becoming characteristic situation low sheltered ample gardens stretching meadows washed stream abbey old neglect prospect scarcely sight abundance timber rows avenues neither fashion extravagance rooted house larger hartfield totally unlike covering good deal ground rambling irregular many comfortable one two handsome rooms ought looked emma felt increasing respect residence family true gentility untainted blood understanding faults temper john knightley isabella connected unexceptionably
#
#
# Original sentence:  dear mrs weston
# Mistyped non-word error sentence:  gearp mrs weston
# Model Output:  heard mrs weston
#
#
# Original sentence:  might weeks might days horse useable preparations could ventured melancholy stagnation
# Mistyped non-word error sentence:  might gmeks might days horse useable preparations could ventured melancholy stagnation
# Model Output:  might games might days horse useable preparations could ventured melancholy stagnation
#
#
# Original sentence:  good send whole way
# Mistyped non-word error sentence:  good send hhople way
# Model Output:  good send whole way
#
#
# Original sentence:  children might stay well
# Mistyped non-word error sentence:  children might ipay well
# Model Output:  children might pay well
#
#
# Original sentence:  ill ill young lady ever allowed look ill
# Mistyped non-word error sentence:  ill ill yzzng lady ever allowed look ill
# Model Output:  ill ill young lady ever allowed look ill
#
#
# Original sentence:  oh
# Mistyped non-word error sentence:  vol
# Model Output:  told
#
#
# Original sentence:  believed foolish alarmed within half minute sending mr perry
# Mistyped non-word error sentence:  believed foolish alarmed within half minute seyndiog mr perry
# Model Output:  believed foolish alarmed within half minute sending mr perry
#
#
# Original sentence:  wonder young man could assurance ask
# Mistyped non-word error sentence:  wonder young man coulgdo assurance ask
# Model Output:  wonder young man could assurance ask
#
#
# Original sentence:  shall stir
# Mistyped non-word error sentence:  shall stiwhr
# Model Output:  shall stir
#
#
# Original sentence:  emma venture take part poor husband
# Mistyped non-word error sentence:  emma qgventure take part poor husband
# Model Output:  emma venture take part poor husband
#
#
# Original sentence:  really ashamed always leading way
# Mistyped non-word error sentence:  really rshahed always leading way
# Model Output:  really ashamed always leading way
#
#
# Original sentence:  least idea weak young man feel sure
# Mistyped non-word error sentence:  least idea weak young mnta feel sure
# Model Output:  least idea weak young mama feel sure
#
#
# Original sentence:  indeed
# Mistyped non-word error sentence:  indrek
# Model Output:  indeed
#
#
# Original sentence:  seemed like forerunner something absolutely serious wish
# Mistyped non-word error sentence:  seemed like forerunner sometfhling absolutely serious wish
# Model Output:  seemed like forerunner something absolutely serious wish
#
#
# Original sentence:  wonder speaks coles calls
# Mistyped non-word error sentence:  wonder spneagks coles calls
# Model Output:  wonder speaks coles calls
#
#
# Original sentence:  want puzzle
# Mistyped non-word error sentence:  wqajnt puzzle
# Model Output:  want puzzle
#
#
# Original sentence:  heard speak acquaintance said emma elegant young woman
# Mistyped non-word error sentence:  heard spterk acquaintance said emma elegant young woman
# Model Output:  heard speak acquaintance said emma elegant young woman
#
#
# Original sentence:  shall go abroad couple years return shall come wife
# Mistyped non-word error sentence:  shafql go abroad couple years return shafql come wife
# Model Output:  shall go abroad couple years return shall come wife
#
#
# Original sentence:  cannot guess parcel holds
# Mistyped non-word error sentence:  ccannovt guess parcel holds
# Model Output:  cannot guess parcel holds
#
#
# Original sentence:  henry fine boy john like mama
# Mistyped non-word error sentence:  henry fine boy john like mxsa
# Model Output:  henry fine boy john like miss
#
#
# Original sentence:  plan arisen sacrifice trusted dearest emma would find respect objectionable received hartfield long father happiness words life required hartfield continue home likewise
# Mistyped non-word error sentence:  plan ariesean sacrifice trusted dearest emma would find respect objectionable received hartfield long father happiness words life required hartfield continue home likewise
# Model Output:  plan arisen sacrifice trusted dearest emma would find respect objectionable received hartfield long father happiness words life required hartfield continue home likewise
#
#
# Original sentence:  air probability sometimes runs dream
# Mistyped non-word error sentence:  air probability sommeiimes runs dream
# Model Output:  air probability sometimes runs dream
#
#
# Original sentence:  one think nothing else
# Mistyped non-word error sentence:  one think lnothiwng else
# Model Output:  one think nothing else
#
#
# Original sentence:  mother often talks good nature
# Mistyped non-word error sentence:  mother ofptcn talks good nature
# Model Output:  mother often talks good nature
#
#
# Original sentence:  soon appeared london place
# Mistyped non-word error sentence:  soon appeared london pklacp
# Model Output:  soon appeared london place
#
#
# Original sentence:  uncle good encroach must still add long letter
# Mistyped non-word error sentence:  uniclpe good encroach must still add long letter
# Model Output:  uncle good encroach must still add long letter
#
#
# Original sentence:
# Mistyped non-word error sentence:  do
# Model Output:  go
#
#
# Original sentence:  cannot imagine suddenly come
# Mistyped non-word error sentence:  cannot ihmagene suddenly come
# Model Output:  cannot imagine suddenly come
#
#
# Original sentence:  would ask pleasure company mr knightley slow walker pace would tedious besides another long walk donwell abbey
# Mistyped non-word error sentence:  would ask pleasure company mr knightley slow walker pace would tedious besides enothr long walk donwell abbey
# Model Output:  would ask pleasure company mr knightley slow walker pace would tedious besides another long walk donwell abbey
#
#
# Original sentence:  upon word air great probability
# Mistyped non-word error sentence:  upon word air rgnat probability
# Model Output:  upon word air great probability
#
#
# Original sentence:  tell aunt little emma ought set better example renewing old grievances wrong
# Mistyped non-word error sentence:  tell aunt little emma ought set better example renewing old sgorievances wrong
# Model Output:  tell aunt little emma ought set better example renewing old grievances wrong
#
#
# Original sentence:  two want
# Mistyped non-word error sentence:  two wqajnt
# Model Output:  two want
#
#
# Original sentence:  know could imagine confess seldom seen face figure pleasing
# Mistyped non-word error sentence:  know could imagine confess seldom seen gfhace figure pleasing
# Model Output:  know could imagine confess seldom seen grace figure pleasing
#
#
# Original sentence:  handsomest man ever man every body looks quite like mr knightley
# Mistyped non-word error sentence:  hxandzsomest man ever man every body looks quite like mr knightley
# Model Output:  handsomest man ever man every body looks quite like mr knightley
#
#
# Original sentence:  strange rumour highbury little perrys seen slice mrs weston wedding cake hands mr woodhouse would never believe
# Mistyped non-word error sentence:  strange rumour jhigheury little perrys seen slice mrs weston wedding cake hands mr woodhouse would never believe
# Model Output:  strange rumour highbury little perrys seen slice mrs weston wedding cake hands mr woodhouse would never believe
#
#
# Original sentence:  knightley never seen life call knightley discover gentleman
# Mistyped non-word error sentence:  knightley never seen life call knightley ndzscover gentleman
# Model Output:  knightley never seen life call knightley discover gentleman
#
#
# Original sentence:  chapter xv
# Mistyped non-word error sentence:  chapter fxd
# Model Output:  chapter fond
#
#
# Original sentence:  see headache
# Mistyped non-word error sentence:  scoe headache
# Model Output:  soon headache
#
#
# Original sentence:  mr woodhouse told
# Mistyped non-word error sentence:  mr woodhouse vol
# Model Output:  mr woodhouse told
#
#
# Original sentence:  alarming change emma thinking one morning must bring great deal agitate grieve mr knightley came distressing thoughts put
# Mistyped non-word error sentence:  alarming change emma thinking one morning must bring great deal agitate grieve mr knightley came distressing thoughtnus put
# Model Output:  alarming change emma thinking one morning must bring great deal agitate grieve mr knightley came distressing thoughtful put
#
#
# Original sentence:  hurried guests prepare father appearance beyond reach mr weston hint
# Mistyped non-word error sentence:  hurried guests prepare father appearance beyond rqeacv mr weston hint
# Model Output:  hurried guests prepare father appearance beyond reach mr weston hint
#
#
# Original sentence:  emma quite loss
# Mistyped non-word error sentence:  emma qwuike loss
# Model Output:  emma quite loss
#
#
# Original sentence:  see consequence keeping company say
# Mistyped non-word error sentence:  see consequence keeping compasnv say
# Model Output:  see consequence keeping company say
#
#
# Original sentence:  mother delighted three months us least
# Mistyped non-word error sentence:  mother deloghved three months us least
# Model Output:  mother delighted three months us least
#
#
# Original sentence:  like mr elton papa must look wife
# Mistyped non-word error sentence:  like mr elton parxpa must look wife
# Model Output:  like mr elton papa must look wife
#
#
# Original sentence:  good natured woman
# Mistyped non-word error sentence:  good nctudred woman
# Model Output:  good natured woman
#
#
# Original sentence:  materially changed since talked subject
# Mistyped non-word error sentence:  materially changed since talkedbd subject
# Model Output:  materially changed since talked subject
#
#
# Original sentence:  jane declares well soon within door well
# Mistyped non-word error sentence:  jane declares well gsloon within door well
# Model Output:  jane declares well soon within door well
#
#
# Original sentence:  mr knightley delightful party last night extremely pleasant ever see dancing delightful miss woodhouse mr frank churchill never saw thing equal
# Mistyped non-word error sentence:  mr knightley delightful party last night extremely pleasant ever scoe dancing delightful miss woodhouse mr frank churchill never saw thing equal
# Model Output:  mr knightley delightful party last night extremely pleasant ever score dancing delightful miss woodhouse mr frank churchill never saw thing equal
#
#
# Original sentence:  backgammon table placed visitor immediately afterwards walked made unnecessary
# Mistyped non-word error sentence:  backgammon table placed visitor immediately afterwards whalmked made unnecessary
# Model Output:  backgammon table placed visitor immediately afterwards walked made unnecessary
#
#
# Original sentence:  really time past least three months cared nothing
# Mistyped non-word error sentence:  really time vasp least three months cared nothing
# Model Output:  really time vast least three months cared nothing
#
#
# Original sentence:  important recordable events productive meetings usually
# Mistyped non-word error sentence:  important recordable events pwrodunctive meetings usually
# Model Output:  important recordable events productive meetings usually
#
#
# Original sentence:  inclines one less bear fair pretence family blood
# Mistyped non-word error sentence:  inclines one less bear fair pretence vfuamily blood
# Model Output:  inclines one less bear fair pretence family blood
#
#
# Original sentence:  fortunate forget precise words one business remember
# Mistyped non-word error sentence:  fortunate forget precise words one business remetpber
# Model Output:  fortunate forget precise words one business remember
#
#
# Original sentence:  feared must decided involvement
# Mistyped non-word error sentence:  feared must decidyzed involvement
# Model Output:  feared must decided involvement
#
#
# Original sentence:  depend upon coming much know parties well
# Mistyped non-word error sentence:  depend upon coming much rqow parties well
# Model Output:  depend upon coming much snow parties well
#
#
# Original sentence:  sorry
# Mistyped non-word error sentence:  scrfy
# Model Output:  sorry
#
#
# Original sentence:  charade obliging leave us thank sight
# Mistyped non-word error sentence:  charade obliging lzeiave us thank sight
# Model Output:  charade obliging leave us thank sight
#
#
# Original sentence:  private resolution communicated least communicated way carry conviction till yesterday know said dark plans
# Mistyped non-word error sentence:  private resolution commrunitcated least commrunitcated way carry conviction till yesterday know said dark plans
# Model Output:  private resolution communicated least communicated way carry conviction till yesterday know said dark plans
#
#
# Original sentence:  tenderest spirit gallantry towards us must let read
# Mistyped non-word error sentence:  tenderest spirit gallantry towaordb us must let read
# Model Output:  tenderest spirit gallantry towards us must let read
#
#
# Original sentence:  nothing compared
# Mistyped non-word error sentence:  nothing compczed
# Model Output:  nothing compared
#
#
# Original sentence:  never known pleasure triumph lucky guess pity thought cleverer depend upon lucky guess never merely luck
# Mistyped non-word error sentence:  nevecyr known pleasure triumph lucky guess pity thought cleverer depend upon lucky guess nevecyr merely luck
# Model Output:  never known pleasure triumph lucky guess pity thought cleverer depend upon lucky guess never merely luck
#
#
# Original sentence:  every respect saw approved confirmed kind designs
# Mistyped non-word error sentence:  every respect saw approzvedg confirmed kind designs
# Model Output:  every respect saw approved confirmed kind designs
#
#
# Original sentence:  dare let mother know little eats say one thing say another passes
# Mistyped non-word error sentence:  dare lftu mother know little eats say one thing say another passes
# Model Output:  dare late mother know little eats say one thing say another passes
#
#
# Original sentence:  grieved find point telling called mrs goddard door last thing returned dress told miss smith better means better rather worse
# Mistyped non-word error sentence:  grieved fiondf point telling called mrs goddard door last thing returned dress told miss smith better means better rather worse
# Model Output:  grieved find point telling called mrs goddard door last thing returned dress told miss smith better means better rather worse
#
#
# Original sentence:  child good fortune
# Mistyped non-word error sentence:  child good zobrtune
# Model Output:  child good fortune
#
#
# Original sentence:  mr mrs weston think strongly persuaded though meaning induced body else give situation believed replete good could change great curiosity see decided intention finding pleasant liked certain degree sort pleasure idea coupled friends imaginations
# Mistyped non-word error sentence:  mr mrs weston think strongly persuaded though meaning induced body else give situation believed reploeqe good could change great curiosity see decided intention finding pleasant liked certain degree sort pleasure idea coupled friends imaginations
# Model Output:  mr mrs weston think strongly persuaded though meaning induced body else give situation believed replete good could change great curiosity see decided intention finding pleasant liked certain degree sort pleasure idea coupled friends imaginations
#
#
# Original sentence:  could satisfied without promise would give influence procuring
# Mistyped non-word error sentence:  coulgdo satisfied without promise would give influence procuring
# Model Output:  could satisfied without promise would give influence procuring
#
#
# Original sentence:  cannot call george
# Mistyped non-word error sentence:  cannot call giokrge
# Model Output:  cannot call george
#
#
# Original sentence:  woman ever excused thinking situation like jane fairfax one may almost say world world law
# Mistyped non-word error sentence:  woman ever excgsedd thinking situation like jane fairfax one may almost say world world law
# Model Output:  woman ever excused thinking situation like jane fairfax one may almost say world world law
#
#
# Original sentence:  want likeness fortunate attitude meant throw little improvement figure give little height considerably elegance great confidence every way pretty drawing last filling destined place credit standing memorial beauty one skill friendship many agreeable associations mr elton promising attachment likely add
# Mistyped non-word error sentence:  want likeness fortunate attitude meant throw little improvement figure give little height csngiderably elegance great confidence every way pretty drawing last filling destined place credit standing memorial beauty one skill friendship many agreeable associations mr elton promising attachment likely add
# Model Output:  want likeness fortunate attitude meant throw little improvement figure give little height considerably elegance great confidence every way pretty drawing last filling destined place credit standing memorial beauty one skill friendship many agreeable associations mr elton promising attachment likely add
#
#
# ...
# Model Output:  sorry sir assure children great deal good
#
#
# Original sentence:  sit write fine flourishing letter full professions falsehoods persuade hit upon best method world preserving peace home preventing father right complain
# Mistyped non-word error sentence:  sit write fine flourishing letter full professions falsehoods persuade hit umpjon best method world preserving peace home preventing father right complain
# Model Output:  sit write fine flourishing letter full professions falsehoods persuade hit upon best method world preserving peace home preventing father right complain
#
#
# Original sentence:  every thing take natural course however neither impelled assisted
# Mistyped non-word error sentence:  every thing take nlaturaml course however neither impelled assisted
# Model Output:  every thing take natural course however neither impelled assisted
#
#
# Original sentence:  sure much surprized first heard going married
# Mistyped non-word error sentence:  sure much surprized first gearp going married
# Model Output:  sure much surprized first heard going married
#
#
# Original sentence:  wife persuading care health happen doubt time little premature
# Mistyped non-word error sentence:  wife persuading care health happen doubt time little prkenature
# Model Output:  wife persuading care health happen doubt time little premature
#
#
# Original sentence:  serious miss woodhouse whatever penetrating eyes may fancy sick england would leave morrow could
# Mistyped non-word error sentence:  serious miss woodhouse whatever penetrating eyes may fancy sick england would leave moqrol could
# Model Output:  serious miss woodhouse whatever penetrating eyes may fancy sick england would leave morrow could
#
#
# Original sentence:  emma thought least
# Mistyped non-word error sentence:  emmve thought least
# Model Output:  emma thought least
#
#
# Original sentence:  oh
# Mistyped non-word error sentence:  vol
# Model Output:  told
#
#
# Original sentence:  think indeed said john knightley pleasantly mr weston little claim
# Mistyped non-word error sentence:  think indeed said john knightley pfeasanthly mr weston little claim
# Model Output:  think indeed said john knightley pleasantly mr weston little claim
#
#
# Original sentence:  shall certainly leisure
# Mistyped non-word error sentence:  shall certkinfly leisure
# Model Output:  shall certainly leisure
#
#
# Original sentence:  strong notion comes
# Mistyped non-word error sentence:  strong nrotpion comes
# Model Output:  strong notion comes
#
#
# Original sentence:  say chose walk six yards door pleasure meeting henry john seen drops could count long
# Mistyped non-word error sentence:  say chose walk six yards door lleasuie meeting henry john seen drops could count long
# Model Output:  say chose walk six yards door pleasure meeting henry john seen drops could count long
#
#
# Original sentence:  supposed must say entitled clemency hard case obliged still lower opinion
# Mistyped non-word error sentence:  supposed must say entitled clemency hard case mbligad still lower opinion
# Model Output:  supposed must say entitled clemency hard case obliged still lower opinion
#
#
# Original sentence:  complete every recommendation _almost_ told loved
# Mistyped non-word error sentence:  ncomplcte every recommendation _almost_ told loved
# Model Output:  complete every recommendation _almost_ told loved
#
#
# Original sentence:  must morning
# Mistyped non-word error sentence:  must lonning
# Model Output:  must running
#
#
# Original sentence:  elton wonder curiosity see
# Mistyped non-word error sentence:  elton wonder ckuriosiny see
# Model Output:  elton wonder curiosity see
#
#
# Original sentence:  jane actually point going governess
# Mistyped non-word error sentence:  jane agtumally point going governess
# Model Output:  jane actually point going governess
#
#
# Original sentence:  mr knightley harriet arrived absence sitting father mr
# Mistyped non-word error sentence:  mr knightley harriet arrived absence sitting mzfather mr
# Model Output:  mr knightley harriet arrived absence sitting father mr
#
#
# Original sentence:  wish distinguishing far civility permitted evident though could often proceed beyond look
# Mistyped non-word error sentence:  wish distinguishing far civility permitted evridyent though could often proceed beyond look
# Model Output:  wish distinguishing far civility permitted evident though could often proceed beyond look
#
#
# Original sentence:  mimic
# Mistyped non-word error sentence:  fimiwc
# Model Output:  mimic
#
#
# Original sentence:  contrivances modern days indeed rendered gentleman carriage perfectly complete
# Mistyped non-word error sentence:  contrivances modern days indeed rendered gentleman cazrrcage perfectly complete
# Model Output:  contrivances modern days indeed rendered gentleman carriage perfectly complete
#
#
# Original sentence:  pray
# Mistyped non-word error sentence:  ipay
# Model Output:  away
#
#
# Original sentence:  extreme sweetness temper must hurt
# Mistyped non-word error sentence:  extreme sweetness temper mxsa hurt
# Model Output:  extreme sweetness temper must hurt
#
#
# Original sentence:  would bad thing much love proper object
# Mistyped non-word error sentence:  would bad thing much love properma object
# Model Output:  would bad thing much love proper object
#
#
# Original sentence:  one shall never change however
# Mistyped non-word error sentence:  one shafql never change however
# Model Output:  one shall never change however
#
#
# Original sentence:  hesitated moment replied ask
# Mistyped non-word error sentence:  hesitated moment breplijed ask
# Model Output:  hesitated moment replied ask
#
#
# Original sentence:  oh
# Mistyped non-word error sentence:  vol
# Model Output:  told
#
#
# Original sentence:  totally different feelings emma take back house brought daring hope little respite suffering exquisite flutter happiness happiness moreover believed must still greater flutter passed away
# Mistyped non-word error sentence:  totpll different feelings emma take back house brought daring hope little respite suffering exquisite flutter happiness happiness moreover believed must still greater flutter passed away
# Model Output:  totally different feelings emma take back house brought daring hope little respite suffering exquisite flutter happiness happiness moreover believed must still greater flutter passed away
#
#
# Original sentence:  cannot believe power coming made point
# Mistyped non-word error sentence:  cannot believe power ominw made point
# Model Output:  cannot believe power owing made point
#
#
# Original sentence:  understood ways could allow ignorance temptations romantic expectations extraordinary virtue education done little entered troubles ready sympathy always gave assistance much intelligence good
# Mistyped non-word error sentence:  understood ways could allow ignorance temptations romantic expectations extraordinary virtue education done little entered troubles ready sympathy always gave assistance much intelligmenct good
# Model Output:  understood ways could allow ignorance temptations romantic expectations extraordinary virtue education done little entered troubles ready sympathy always gave assistance much intelligent good
#
#
# Original sentence:  affection man mr elton would great distinction never could deserved nobody partial kind friend miss woodhouse would thought possible
# Mistyped non-word error sentence:  affection man mrqg elton would great distinction never could deserved nobody partial kind friend miss woodhouse would thought possible
# Model Output:  affection man mr elton would great distinction never could deserved nobody partial kind friend miss woodhouse would thought possible
#
#
# Original sentence:  one cannot resolve upon hurry
# Mistyped non-word error sentence:  one cannot resolve umpjon hurry
# Model Output:  one cannot resolve upon hurry
#
#
# Original sentence:  mentioned mrs dixon felt much probable tribute warm female friendship
# Mistyped non-word error sentence:  mentioned mrs dixon felt much probable ltributve warm female friendship
# Model Output:  mentioned mrs dixon felt much probable tribute warm female friendship
#
#
# Original sentence:  dear clever could really meant
# Mistyped non-word error sentence:  dear clever could really mtanti
# Model Output:  dear clever could really meant
#
#
# Original sentence:  ladies never look ill seriously miss fairfax naturally pale almost always give appearance ill health deplorable want complexion
# Mistyped non-word error sentence:  ltadiwes never look ill seriously miss fairfax naturally pale almost always give appearance ill health deplorable want complexion
# Model Output:  ladies never look ill seriously miss fairfax naturally pale almost always give appearance ill health deplorable want complexion
#
#
# Original sentence:  occasion press matter farther
# Mistyped non-word error sentence:  occasion jpreses matter farther
# Model Output:  occasion press matter farther
#
#
# Original sentence:  certainly get better better
# Mistyped non-word error sentence:  certkinfly get better better
# Model Output:  certainly get better better
#
#
# Original sentence:  give carte blanche lady patroness know
# Mistyped non-word error sentence:  give carte blanche lady patrsnesl know
# Model Output:  give carte blanche lady patroness know
#
#
# Original sentence:  poor old john great regard clerk poor father twenty seven years poor old man bed ridden poorly rheumatic gout joints must go see day jane sure gets
# Mistyped non-word error sentence:  poor old john great regard clerk poor father twenty seven years poor old man bed ridden poorly rheumatic gout joints mxsa go see day jane sure gets
# Model Output:  poor old john great regard clerk poor father twenty seven years poor old man bed ridden poorly rheumatic gout joints must go see day jane sure gets
#
#
# Original sentence:  miss woodhouse quite concerned sure hit foot
# Mistyped non-word error sentence:  miss woodpousl quite concerned sure hit foot
# Model Output:  miss woodhouse quite concerned sure hit foot
#
#
# Original sentence:  poor little anna weston spoiled greatest humanity much done except falling love thirteen
# Mistyped non-word error sentence:  poor little anna weston spoiled greatest humanity much done except falling love yhirteein
# Model Output:  poor little anna weston spoiled greatest humanity much done except falling love thirteen
#
#
# Original sentence:  sitting appeared companionably home till usual hour exercise desired chuse walk immediately fixed highbury doubt pleasant walks every direction left always chuse
# Mistyped non-word error sentence:  sitting appeared companionably home till usual hour exercise desired chuse walk immieziately fixed highbury doubt pleasant walks every direction left always chuse
# Model Output:  sitting appeared companionably home till usual hour exercise desired chuse walk immediately fixed highbury doubt pleasant walks every direction left always chuse
#
#
# Original sentence:  think come shall think know enscombe
# Mistyped non-word error sentence:  think come shafql think know enscombe
# Model Output:  think come shall think know enscombe
#
#
# Original sentence:  never seen frank churchill silent stupid
# Mistyped non-word error sentence:  never seen frank czmhurchill silent stupid
# Model Output:  never seen frank churchill silent stupid
#
#
# Original sentence:  mr knightley hard work upon lower buttons thick leather gaiters either exertion getting together cause brought colour face answered
# Mistyped non-word error sentence:  mr knightley hard work upon lower buttons thick leather gaiters either exertpioo getting together cause brought colour face answered
# Model Output:  mr knightley hard work upon lower buttons thick leather gaiters either exertion getting together cause brought colour face answered
#
#
# Original sentence:  thoroughly understand telling brother cried emma friend mr graham intending bailiff scotland look new estate
# Mistyped non-word error sentence:  thoroughly junderpstand telling brother cried emma friend mr graham intending bailiff scotland look new estate
# Model Output:  thoroughly understand telling brother cried emma friend mr graham intending bailiff scotland look new estate
#
#
# Original sentence:  met letters way morning seeing son hand presumed open though directed mrs weston
# Mistyped non-word error sentence:  met letters way morning seeing son hand presumed open though diflrected mrs weston
# Model Output:  met letters way morning seeing son hand presumed open though directed mrs weston
#
#
# Original sentence:  never quite well since time daughter marriage till completely recovered usual strength must forbid engaging duties far compatible weakened frame varying spirits seemed favourable circumstances require something human perfection body mind discharged tolerable comfort
# Mistyped non-word error sentence:  never quite well since time daughter marriage till completely recovered usual strength must forbid engaging duties far compatible weakened frame oaryfing spirits seemed favourable circumstances require something human perfection body mind discharged tolerable comfort
# Model Output:  never quite well since time daughter marriage till completely recovered usual strength must forbid engaging duties far compatible weakened frame varying spirits seemed favourable circumstances require something human perfection body mind discharged tolerable comfort
#
#
# Original sentence:  exceedingly sorry well mistake ends
# Mistyped non-word error sentence:  exbhedingly sorry well mistake ends
# Model Output:  exceedingly sorry well mistake ends
#
#
# Original sentence:  weston may grow cross wantonness comfort son may plague
# Mistyped non-word error sentence:  weston may grow cross wcntonnbss comfort son may plague
# Model Output:  weston may grow cross wantonness comfort son may plague
#
#
# Original sentence:  advise custard
# Mistyped non-word error sentence:  advise austards
# Model Output:  advise custard
#
#
# Original sentence:  would affect frank among earliest thoughts
# Mistyped non-word error sentence:  would affect frank among yearlijest thoughts
# Model Output:  would affect frank among earliest thoughts
#
#
# Original sentence:  great commonly thankful delight towards mrs elton emma guessed little show resentment towards jane vicarage quarter graciously overcome whispers indeed placed beyond guess mrs elton speaking louder said
# Mistyped non-word error sentence:  rgnat commonly thankful delight towards mrs elton emma guessed little show resentment towards jane vicarage quarter graciously overcome whispers indeed placed beyond guess mrs elton speaking louder said
# Model Output:  great commonly thankful delight towards mrs elton emma guessed little show resentment towards jane vicarage quarter graciously overcome whispers indeed placed beyond guess mrs elton speaking louder said
#
#
# Original sentence:  mrs dixon must much disappointed
# Mistyped non-word error sentence:  mrs dixon mxsa much disappointed
# Model Output:  mrs dixon miss much disappointed
#
#
# Original sentence:  considering particular friendship mrs dixon could hardly expected excused accompanying colonel mrs
# Mistyped non-word error sentence:  considering particular friendship mrs dixon could hardly expected excgsedd accompanying colonel mrs
# Model Output:  considering particular friendship mrs dixon could hardly expected excused accompanying colonel mrs
#
#
# Original sentence:  every thing said done many weeks past sole view marking adoration
# Mistyped non-word error sentence:  every thing said dois many weeks past sole view marking adoration
# Model Output:  every thing said dies many weeks past sole view marking adoration
#
#
# Original sentence:  thank
# Mistyped non-word error sentence:  thawunk
# Model Output:  thank
#
#
# Original sentence:  really well observed nothing course seems new idea think made discoveries
# Mistyped non-word error sentence:  really well observed nothing course seems new idea think saee discoveries
# Model Output:  really well observed nothing course seems new idea think sake discoveries
#
#
# Original sentence:  know tempers manage
# Mistyped non-word error sentence:  rqow tempers manage
# Model Output:  snow tempers manage
#
#
# The accuracy is: 75.38860103626943

# %% [markdown]
# ## Real World Error

# %%
# (1) Change the word to something present in the vocab 
# (2) for each word generate candidate words within 1,2 edit distance and original word.... 3 in each
# (3) generate all possible combinations and find the best sentence according to probability 

def accuracy_realword(test_corpus, vocab):

  correct = 0
  tp = [preprocess_sentence(" ".join(s)) for s in test_corpus]

  for sentence in tp:
    #randomly choose a word and modify within 2 edit distance such that it lies in the vocabulary. 

    split_s = sentence.split(" ")
    random_index = random.randint(0, len(split_s)-1)

    word = split_s[random_index]

    possible_words = set(list(edit_distance1(word)) + list(edit_distance2(word)))
    final_pw = list(possible_words.intersection(set(vocab.keys())))

    incorrect_s = sentence.replace(word, final_pw[0])

    #for each word in the incorrect sentence generate all possible sentences and find the highest probability 

    #candidate word 1 
    #candidate word 2

    inc_splits = incorrect_s.split(" ")
    sentences_probable = [] 

    for w in inc_splits:
      for cw in top_k(w,vocab,2):
        sentences_probable.append(incorrect_s.replace(w,cw))

    sentences_probable.sort(reverse = True, key = bigram.sentence_prob)

    print("Original sentence: ", sentence)
    print("Mistyped non-word error sentence: ", incorrect_s)
    print("Model Output: ", sentences_probable[0])
    print("\n")

    if sentences_probable[0] == sentence:
      correct +=1
    
  return correct / len(tp)

# %%
print("Accuracy for Real World is:", accuracy_realword(test,vocab))
# Out:
# Streaming output truncated to the last 5000 lines.
# Mistyped non-word error sentence:  extent adoration may take surprize day
# Model Output:  extent adoration may taken surprize day
#
#
# Original sentence:  hope retract said
# Mistyped non-word error sentence:  hows retract said
# Model Output:  shows retract said
#
#
# Original sentence:  owned considering every thing absolutely without inclination party
# Mistyped non-word error sentence:  owes considering every thing absolutely without inclination party
# Model Output:  owes considering every thing absolutely without inclination party
#
#
# Original sentence:  gave understand frank admired extremely thought beautiful charming much said altogether found must judge harshly
# Mistyped non-word error sentence:  gave understand frank admired extremely thought beautiful charming much said altogether found must judge harshly
# Model Output:  gave understand frank admired extremely thought beautiful charming much said altogether found must judge harshly
#
#
# Original sentence:  better order carriage directly love said dare say shall able get along set directly come thing bad get walk
# Mistyped non-word error sentence:  better order carriage directly moved said dare say shall able get along set directly come thing bad get walk
# Model Output:  better order carriage directly moved said dare say shall able get along set directly come things bad get walk
#
#
# Original sentence:  friend knightley often mentioned really impatient see must caro sposo justice say need ashamed friend
# Mistyped non-word error sentence:  friend knightley often mentioned weakly impatient see must caro sposo justice say need ashamed friend
# Model Output:  friend knightley often mentioned weakly impatient see must caro sposo justice say need ashamed friend
#
#
# Original sentence:  emma thinking moment made information received valuable
# Mistyped non-word error sentence:  emma thinking comment made information received valuable
# Model Output:  emma thinking comment made information received valuable
#
#
# Original sentence:  first error worst lay door
# Mistyped non-word error sentence:  fires error worst lay door
# Model Output:  fires error worst lay poor
#
#
# Original sentence:  recollect clever way
# Mistyped non-word error sentence:  recollect never way
# Model Output:  recollect never way
#
#
# Original sentence:  wrong know keep remembrances married
# Mistyped non-word error sentence:  iron know keep remembrances married
# Model Output:  iron know keep remembrances married
#
#
# Original sentence:  believed share feelings would wretched
# Mistyped non-word error sentence:  relieved share feelings would wretched
# Model Output:  believed share feelings would wretched
#
#
# Original sentence:  ever might feel brighter hope betrayed nothing
# Mistyped non-word error sentence:  ever might feel brighter hope betrayed nothing
# Model Output:  every might feel brighter hope betrayed nothing
#
#
# Original sentence:  turning mr knightley know seldom ever two hours hartfield foresee series dissipation cannot imagine
# Mistyped non-word error sentence:  turning mr knightley know seldom ever two hours hartfield foresee series dissipation cannot imagine
# Model Output:  turning mr knightley know seldom ever two hours hartfield foresee series dissipation cannot imagine
#
#
# Original sentence:  obliged go evening call duty business hardship deem probably rather thinner clothing usual setting forward voluntarily without excuse defiance voice nature tells man every thing given view feelings stay home keep shelter setting forward spend five dull hours another man house nothing say hear said heard yesterday may said heard morrow
# Mistyped non-word error sentence:  obliged go evening call duty business hardship deem probably rather thinner clothing usual setting forward voluntarily without excuse defiance voice nature tells gain every thing given view feelings stay home keep shelter setting forward spend five dull hours another gain house nothing say hear said heard yesterday may said heard morrow
# Model Output:  obliged go evening call duty business hardship deem probably rather thinner clothing usual setting forward voluntarily without excuse defiance voice nature tells gain every thing given view feelings stay home keep shelter setting forward spend five dull hours another gain house nothing say heard said heardd yesterday may said heardd morrow
#
#
# Original sentence:  see
# Mistyped non-word error sentence:  led
# Model Output:  let
#
#
# Original sentence:  poverty certainly contracted mind really believe shilling world would likely give away sixpence nobody afraid great charm
# Mistyped non-word error sentence:  poverty certainly contracted mind really believe shilling world would likely give war sixpence nobody afraid great charm
# Model Output:  poverty certainly contracted mind really believe shilling world would likely give war sixpence nobody afraid great harm
#
#
# Original sentence:  well done mrs
# Mistyped non-word error sentence:  welch done mrs
# Model Output:  welch done mr
#
#
# Original sentence:  mention names happy man changes emma harriet
# Mistyped non-word error sentence:  mention names happy man changes emma marries
# Model Output:  mention names happy man changes emma married
#
#
# Original sentence:  never saw thing hard
# Mistyped non-word error sentence:  river saw thing hard
# Model Output:  river saw thing heard
#
#
# Original sentence:  john loves emma reasonable therefore blind affection isabella always thinks except quite frightened enough children
# Mistyped non-word error sentence:  john loves emma unreasonable therefore blind affection isabella always thinks except quite frightened enough children
# Model Output:  john loves emma unreasonable therefore blind affection isabella always think except quite frightened enough children
#
#
# Original sentence:  must given
# Mistyped non-word error sentence:  must river
# Model Output:  must rivet
#
#
# Original sentence:  _her_ connexions may worse _his_
# Mistyped non-word error sentence:  _ten_ connexions may worse _his_
# Model Output:  _then_ connexions may worse _his_
#
#
# Original sentence:  pray take care mrs weston step turning
# Mistyped non-word error sentence:  pray take care mrs weston step turning
# Model Output:  pray take care mrs weston step turning
#
#
# Original sentence:  soon flies present failure begins hope
# Mistyped non-word error sentence:  soon flies presented failure begins hope
# Model Output:  soon flies presented failure begins hope
#
#
# Original sentence:  drawings always dear
# Mistyped non-word error sentence:  drawings always dream
# Model Output:  drawing always dream
#
#
# Original sentence:  goldsmith tells us lovely woman stoops folly nothing die stoops disagreeable equally recommended clearer ill fame
# Mistyped non-word error sentence:  goldsmith tells us lovely woman stoops folly nothing die stoops disagreeable equally commended clearer ill fame
# Model Output:  goldsmith tells us lovely woman stoops folly nothing die stoops disagreeable equally commended cleared ill fame
#
#
# Original sentence:  dear sir upon account world father direct
# Mistyped non-word error sentence:  dear sir upon account world father direct
# Model Output:  dear sir upon account world father directly
#
#
# Original sentence:  cried emma feelingly
# Mistyped non-word error sentence:  cried elms feelingly
# Model Output:  cried elms feelingly
#
#
# Original sentence:  heart
# Mistyped non-word error sentence:  heard
# Model Output:  heard
#
#
# Original sentence:  emma said paper worse expected
# Mistyped non-word error sentence:  emma said paper work expected
# Model Output:  emma said paper work expected
#
#
# Original sentence:  frank standing steadily restlessness shewed mind ease
# Mistyped non-word error sentence:  frank standing steadily restlessness shewed minced ease
# Model Output:  frank standing steadily restlessness shewed minced case
#
#
# Original sentence:  observed mrs elton course life things going untowardly one month sure mend next
# Mistyped non-word error sentence:  observed mrs eltons course life things going untowardly one month sure mend next
# Model Output:  observed mr eltons course life things going untowardly one month sure mend next
#
#
# Original sentence:  happy hear jane fairfax one knows accomplished superior exactly emma age
# Mistyped non-word error sentence:  happy hear jane fairfax one knows accomplished superior exactly emma age
# Model Output:  happy heard jane fairfax one knows accomplished superior exactly emma age
#
#
# Original sentence:  ah
# Mistyped non-word error sentence:
# Model Output:
#
#
# Original sentence:  honestly said much mr e speaking future home expressing fears lest retirement disagreeable inferiority house knowing accustomed course wholly without apprehension
# Mistyped non-word error sentence:  honestly said much mr e speaking future home expressing fears lest retirement disagreeables inferiority house knowing accustomed course wholly without apprehension
# Model Output:  honestly said much mr e speaking future home expressing fears lest retirement disagreeables inferiority house knowing accustomed course wholly without apprehension
#
#
# Original sentence:  glad made play much instrument grandmother must real indulgence
# Mistyped non-word error sentence:  glad made play vouch instrument grandmother must real indulgence
# Model Output:  glad made play vouch instrument grandmother must real indulgence
#
#
# Original sentence:  mrs weston friends made happy safety satisfaction well could increased emma knowing mother little girl
# Mistyped non-word error sentence:  mrs weston friends made happy safety satisfaction welch could increased emma knowing mother little girl
# Model Output:  mrs weston friends made happy safety satisfaction welch could increased emma knowing mother little girl
#
#
# Original sentence:  gone three miles round one day order bring walnuts said fond every thing else obliging
# Mistyped non-word error sentence:  gfond three miles round fond day order bring walnuts said fond every thing else obliging
# Model Output:  gfood three miles round food day order bring walnuts said food every thing else obliging
#
#
# Original sentence:  impossible never call thing mr
# Mistyped non-word error sentence:  impossible never caps thing mr
# Model Output:  impossible never caps things mr
#
#
# Original sentence:  made tall emma said mr knightley
# Mistyped non-word error sentence:  made tall emma said mr knightleys
# Model Output:  made tall emma said mr knightley
#
#
# Original sentence:  shall leave well
# Mistyped non-word error sentence:  ball leave well
# Model Output:  ball leave well
#
#
# Original sentence:  one cannot large party
# Mistyped non-word error sentence:  fond cannot large party
# Model Output:  fond cannot larger party
#
#
# Original sentence:  certainly persuade feel
# Mistyped non-word error sentence:  certainly persuaded feel
# Model Output:  certainly persuaded feel
#
#
# Original sentence:  thing attentive
# Mistyped non-word error sentence:  thing attention
# Model Output:  thing attention
#
#
# Original sentence:  say quite invalid go therefore must decline obliging invitation beginning _compliments_ course
# Mistyped non-word error sentence:  say quite invalid go therefore must decline obliging invitation beginning _compliments_ course
# Model Output:  say quite invalid go therefore must declined obliging invitation beginning _compliments_ course
#
#
# Original sentence:  dining coles ball talked never took place
# Mistyped non-word error sentence:  dining coles ball talked river took place
# Model Output:  dining coles ball talked river took place
#
#
# Original sentence:  consider partial quarter information came
# Mistyped non-word error sentence:  consider partial quarters information came
# Model Output:  consider partial quarters information came
#
#
# Original sentence:  manner perhaps may little recommend
# Mistyped non-word error sentence:  manner perhaps may little recommend
# Model Output:  manner perhaps may little recommend
#
#
# Original sentence:  perhaps ought ashamed mr weston almost uneasy ten minutes however child perfectly well
# Mistyped non-word error sentence:  perhaps ought ashamed mr weston almost uneasy ten minutes however child perfectly well
# Model Output:  perhaps ought ashamed mr weston almost uneasy ten minutes however child perfectly well
#
#
# Original sentence:  elton
# Mistyped non-word error sentence:  eltons
# Model Output:  elton
#
#
# Original sentence:  know time
# Mistyped non-word error sentence:  know lie
# Model Output:  know lie
#
#
# Original sentence:  young uncle perhaps
# Mistyped non-word error sentence:  young uncle perhaps
# Model Output:  young uncle perhaps
#
#
# Original sentence:  forget take friend message miss smith shall happy deliver _me_ please
# Mistyped non-word error sentence:  forget take cried message miss smith shall happy deliver _me_ please
# Model Output:  forget take cried message miss smith shall happy deliver _me_ pleased
#
#
# Original sentence:  minutes entire silence john knightley began
# Mistyped non-word error sentence:  minutes entire since john knightley began
# Model Output:  minutes entire since john knightley began
#
#
# Original sentence:  avowedly due _her_
# Mistyped non-word error sentence:  avowedly due _ten_
# Model Output:  avowedly due _then_
#
#
# Original sentence:  went however
# Mistyped non-word error sentence:  went however
# Model Output:  went however
#
#
# Original sentence:  seemed like cheerful easy friends lovers
# Mistyped non-word error sentence:  seemed like cheerful easy friends lovers
# Model Output:  seemed like cheerful easy friends loves
#
#
# Original sentence:  think would much better would come one afternoon next summer take tea us take us afternoon walk might hours reasonable yet get home without damp evening
# Mistyped non-word error sentence:  think would much letter would come one afternoon next summer take tea us take us afternoon walk might hours reasonable yet get home without damp evening
# Model Output:  think would much letter would come one afternoon next summer take tea us take us afternoon walk might hours reasonable yet get home without damp evening
#
#
# Original sentence:  bring new proposal subject thought father waits approbation acted upon
# Mistyped non-word error sentence:  bring new proposal subject thought father waste approbation acted upon
# Model Output:  bring new proposal subject thought father waste approbation acted upon
#
#
# Original sentence:  meant immediately mixed others buried sight looked table instead looking across mixed harriet eager every fresh word finding none directly took fell work
# Mistyped non-word error sentence:  meant immediately mixed others buried sight looked pale instead looking across mixed harriet eager every fresh word finding none directly took fell work
# Model Output:  mean immediately mixed others buried sight looked pale instead looking across mixed harriet eager every fresh word finding none directly took fell work
#
#
# Original sentence:  pain obliged practise concealment towards little inferior pain made harriet unhappy
# Mistyped non-word error sentence:  pale obliged practise concealment towards little inferior pale made harriet unhappy
# Model Output:  pale obliged practise concealment towards little inferior pale made harriet happy
#
#
# Original sentence:  entirely without think
# Mistyped non-word error sentence:  entirely without thin
# Model Output:  entirely without thing
#
#
# Original sentence:  try find miss woodhouse
# Mistyped non-word error sentence:  try find remiss woodhouse
# Model Output:  try find remiss woodhouse
#
#
# Original sentence:  dear harriet must refine much upon charade betray feelings improperly conscious quick appear affix meaning even quite meaning may affixed
# Mistyped non-word error sentence:  dream harriet must refine much upon charade betray feelings improperly conscious quick appear affix meaning even quite meaning may affixed
# Model Output:  dream harriet must refine much upon charade betray feelings improperly conscious quick appear affix meaning even quite meaning may fixed
#
#
# Original sentence:  miss smith miss fairfax three two miss coxes five five couple plenty room
# Mistyped non-word error sentence:  miss smith miss fairfax three two miss coxes river river couple plenty room
# Model Output:  miss smith miss fairfax three two miss coxes river river couple plenty room
#
#
# Original sentence:  excepting brother know equal temper
# Mistyped non-word error sentence:  excepting brother row equal temper
# Model Output:  excepting brother row equal temper
#
#
# Original sentence:  could change shoes know moment got home sort thing gives cold
# Mistyped non-word error sentence:  could channel shoes know moment got home sort thing gives cold
# Model Output:  could channel shoes know moment got home sort thing give cold
#
#
# Original sentence:  told observe carefully let behaviour rule mine
# Mistyped non-word error sentence:  told observe careful let behaviour rule mine
# Model Output:  told observe careful let behaviour rule mine
#
#
# Original sentence:  june soon
# Mistyped non-word error sentence:  sun soon
# Model Output:  run soon
#
#
# Original sentence:  keep horses moment
# Mistyped non-word error sentence:  sleep horses moment
# Model Output:  sweep horses moment
#
#
# Original sentence:  may well say lot cast goodly heritage
# Mistyped non-word error sentence:  may well say lot cast fondly heritage
# Model Output:  may well say lot cast fondly heritage
#
#
# Original sentence:  _i_ sick prosperity indulgence
# Mistyped non-word error sentence:  _i_ sick property indulgence
# Model Output:  _i_ sick property indulgence
#
#
# Original sentence:  emma good deal surprized begged speak
# Mistyped non-word error sentence:  emma good debt surprized begged speak
# Model Output:  emma good debt surprized begged speak
#
#
# Original sentence:  find making use word _sacrifice_ said one clever replies delicate negatives allusion making sacrifice
# Mistyped non-word error sentence:  find making use word _sacrifice_ said fond clever replies delicate negatives allusion making sacrifice
# Model Output:  find making use word _sacrifice_ said fond clever replies delicate negatives allusion making sacrifice
#
#
# Original sentence:  occasion marry either fill time heart
# Mistyped non-word error sentence:  occasion marry either fine time heart
# Model Output:  occasion marry either fine time heard
#
#
# Original sentence:  know
# Mistyped non-word error sentence:  row
# Model Output:  bow
#
#
# Original sentence:  joy gratitude exquisite delight sensations may imagined
# Mistyped non-word error sentence:  row gratitude exquisite delight sensations may imagined
# Model Output:  row gratitude exquisite delight sensations may imagine
#
#
# Original sentence:  _miss_ _woodhouse_ appeared never without something pleasing connexion either compliment taste remembrance said last time meeting eye unadorned broad wreath gallantry yet could discern effect influence acknowledge greatest compliment perhaps conveyed
# Mistyped non-word error sentence:  _miss_ _woodhouse_ appeared never without something pleasing connexion either compliment taste remembrance said last time meeting eye unadorned broad wreath gallantry yet could discern effect influence acknowledge greatest compliment perhaps conveyed
# Model Output:  _miss_ _woodhouse_ appeared ever without something pleasing connexion either compliment taste remembrance said last time meeting eye unadorned broad wreath gallantry yet could discern effect influence acknowledge greatest compliment perhaps conveyed
#
#
# Original sentence:  _we_ set example many follow far though situations
# Mistyped non-word error sentence:  _we_ set example many followed far though situations
# Model Output:  _we_ set example many followed far though situation
#
#
# Original sentence:  could enter house could room vain artifice retreated three months ago lace boot without _recollecting_
# Mistyped non-word error sentence:  told enter house told room vain artifice retreated three months ago lace boot without _recollecting_
# Model Output:  told enter house told room vain artifice retreated three months ago lace boot without _recollecting_
#
#
# Original sentence:  emma infatuation girl blinds
# Mistyped non-word error sentence:  emma infatuation girl brings
# Model Output:  emma infatuation girl brings
#
#
# Original sentence:  yes quite proposal marriage good letter least thought
# Mistyped non-word error sentence:  yes quite proposal marriage good leather least thought
# Model Output:  yes quite proposal marriage good leather least thought
#
#
# Original sentence:  got hannah good place
# Mistyped non-word error sentence:  got hannah good place
# Model Output:  got hannah good pace
#
#
# Original sentence:  nothing wrong escaped
# Mistyped non-word error sentence:  nothing wrong escape
# Model Output:  nothing wrong escape
#
#
# Original sentence:  playing _robin_ _adair_ moment _his_ favourite
# Mistyped non-word error sentence:  playing _robin_ _adair_ moment _mrs_ favourite
# Model Output:  playing _robin_ _adair_ moment _mrs_ favourite
#
#
# Original sentence:  places town offices inquiry would soon produce something offices sale quite human flesh human intellect
# Mistyped non-word error sentence:  places town office inquiry would soon produce something office sale quite human flesh human intellect
# Model Output:  placed town office inquiry would soon produce something office sale quite human flesh human intellect
#
#
# Original sentence:  feared every body else must think predict
# Mistyped non-word error sentence:  feared every body else must think credit
# Model Output:  heard every body else must think credit
#
#
# Original sentence:  emma extremely confused
# Mistyped non-word error sentence:  emma extreme confused
# Model Output:  emma extreme confused
#
#
# Original sentence:  mean return favourable answer collect
# Mistyped non-word error sentence:  head return favourable answer collect
# Model Output:  head return favourable answer collect
#
#
# Original sentence:  oh
# Mistyped non-word error sentence:
# Model Output:
#
#
# Original sentence:  regard receiving strength invariable praise regrets kept alive feelings irritated ceaseless repetitions miss hawkins happiness continual observation much seemed attached air walked house sitting hat proof much love
# Mistyped non-word error sentence:  regard receiving strength invariable praise regrets kept alive feelings irritated ceaseless repetitions miss hawkins happiness continual observation much seemed attached gain walked house sitting hat proof much love
# Model Output:  regard receiving strength invariable praise regrets kept alive feelings irritated ceaseless repetitions miss hawkins happiness continual observation much seemed attached rain walked house sitting hat proof much love
#
#
# Original sentence:  dixon well
# Mistyped non-word error sentence:  iron well
# Model Output:  iron well
#
#
# Original sentence:  oh yes great difference
# Mistyped non-word error sentence:  oh yes great inference
# Model Output:  oh yes great influence
#
#
# Original sentence:  sure opinions
# Mistyped non-word error sentence:  sure opinion
# Model Output:  sure opinion
#
#
# Original sentence:  shews sad invalid
# Mistyped non-word error sentence:  shews sad invalids
# Model Output:  shows sad invalids
#
#
# Original sentence:  oh
# Mistyped non-word error sentence:
# Model Output:
#
#
# Original sentence:  companion tells said absolutely promised miss bates last night would come morning
# Mistyped non-word error sentence:  compassion tells said absolutely promised miss bates last night would come morning
# Model Output:  compassion tell said absolutely promised miss bates last night would come morning
#
#
# Original sentence:  extremely fond danger surely
# Mistyped non-word error sentence:  extreme fond danger surely
# Model Output:  extreme fond danger merely
#
#
# Original sentence:  call another day hear pianoforte
# Mistyped non-word error sentence:  call another thy hear pianoforte
# Model Output:  call another thy hear pianoforte
#
#
# Original sentence:  article fully acquit
# Mistyped non-word error sentence:  article fully acquit
# Model Output:  article fully acquire
#
#
# Original sentence:  misery suffered concealment many months continued mrs weston energetic
# Mistyped non-word error sentence:  misery suffered concealment many months continued mrs weston energetic
# Model Output:  misery suffered concealment many months continued mrs weston energetic
#
#
# Original sentence:  well coming see good news think
# Mistyped non-word error sentence:  well coming see good news thin
# Model Output:  well coming see good news thing
#
#
# Original sentence:  striving look taller body else
# Mistyped non-word error sentence:  thriving look taller body else
# Model Output:  arriving look taller body else
#
#
# Original sentence:  introducing good company giving opportunity pleasing one worth ought attempted
# Mistyped non-word error sentence:  introducing good company giving opportunity pleasing one worth ought attempted
# Model Output:  introducing good company giving opportunity pleasing one worth ought attempted
#
#
# Original sentence:  idea mr knightley returning affection
# Mistyped non-word error sentence:  idea mr knightleys returning affection
# Model Output:  idea mr knightley returning affection
#
#
# Original sentence:  weston judge us
# Mistyped non-word error sentence:  weston judge us
# Model Output:  weston judge us
#
#
# Original sentence:  mr frank churchill indeed
# Mistyped non-word error sentence:  mr bank churchill indeed
# Model Output:  mr bank churchill indeed
#
#
# Original sentence:  deficient nothing make amends
# Mistyped non-word error sentence:  deficient clothing make amends
# Model Output:  deficient clothing make amends
#
#
# Original sentence:  _she_ certainly wrong _he_ would never
# Mistyped non-word error sentence:  _she_ certainly wrong _he_ would never
# Model Output:  _she_ certainly wrong _he_ would never
#
#
# Original sentence:  cheerful animated suspicious busy imaginations
# Mistyped non-word error sentence:  cheerful animated suspicions busy imaginations
# Model Output:  cheerful animated suspicions busy imagination
#
#
# Original sentence:  mentioned _names_ observe oh
# Mistyped non-word error sentence:  unmentioned _names_ observe oh
# Model Output:  mentioned _names_ observe oh
#
#
# Original sentence:  excuse much powered
# Mistyped non-word error sentence:  expose much powered
# Model Output:  expose much power
#
#
# Original sentence:  owed risk thing might involved unwelcome interference rather welfare encounter thing rather remembrance neglect cause
# Mistyped non-word error sentence:  owed risk thing might involved welcome interference rather welfare encounter thing rather remembrance neglect cause
# Model Output:  owed risk things might involved welcome interference rather welfare encounter things rather remembrance neglect cause
#
#
# Original sentence:  seen country afraid think overrated hartfield
# Mistyped non-word error sentence:  seen counter afraid think overrated hartfield
# Model Output:  seen counter afraid think overrated hartfield
#
#
# Original sentence:  taken place year would grievance
# Mistyped non-word error sentence:  taken place heard would grievance
# Model Output:  taken place heard would grievance
#
#
# Original sentence:  always patience could wished
# Mistyped non-word error sentence:  otways patience could wished
# Model Output:  otway patience could wished
#
#
# Original sentence:  hoped time
# Mistyped non-word error sentence:  moved time
# Model Output:  loved time
#
#
# Original sentence:  mr knightley always kind feeling truly considerate every body would never deserve less worshipped really much hope even harriet could love _three_ men one year
# Mistyped non-word error sentence:  mr knightleys always kind feeling truly considerate every body would never deserve less worshipped really much hope even harriet could love _three_ men one year
# Model Output:  mr knightley always kind feeling truly considerate every body would never deserve less worshipped really much hope even harriet could love _three_ men one year
#
#
# Original sentence:  tell letter dear said father
# Mistyped non-word error sentence:  tell letter dear gain father
# Model Output:  tell letter dear gain father
#
#
# Original sentence:  taken pains sake robert martin sake always reason believe much love ever get acquainted
# Mistyped non-word error sentence:  taken pains sake robert martin sake always reason relieved much love ever get acquainted
# Model Output:  taken pains sake robert martin sake always reason relieved much love ever get acquainted
#
#
# Original sentence:  cried emma collecting resolutely let us understand without possibility farther mistake
# Mistyped non-word error sentence:  cried emma collecting resolutely let us understand without possibility farther mistake
# Model Output:  cried emma collecting resolutely let us understand without possibility farther mistake
#
#
# Original sentence:  dear affectionate creature _you_ banished abbey mill farm _you_ confined society illiterate vulgar life
# Mistyped non-word error sentence:  dear affectionate creature _you_ banished abbey miles farm _you_ confined society illiterate vulgar life
# Model Output:  dear affectionate creature _you_ banished abbey miles farm _you_ confined society illiterate vulgar life
#
#
# Original sentence:  felt honest pride complacency alliance present future proprietor could fairly warrant viewed respectable size style building suitable becoming characteristic situation low sheltered ample gardens stretching meadows washed stream abbey old neglect prospect scarcely sight abundance timber rows avenues neither fashion extravagance rooted house larger hartfield totally unlike covering good deal ground rambling irregular many comfortable one two handsome rooms ought looked emma felt increasing respect residence family true gentility untainted blood understanding faults temper john knightley isabella connected unexceptionably
# Mistyped non-word error sentence:  felt honest pride complacency alliance present future proprietor could fairly warrant viewed respectable size style building suitable becoming characteristic situation low sheltered ample gardens stretching meadows washed stream abbey old neglect prospect scarcely sight abundance timber rows avenues neither fashion extravagance rooted house larger hartfield totally unlike covering good deal round rambling irregular many comfortable one two handsome rooms ought looked emma felt increasing respect residence family true gentility untainted blood understanding faults temper john knightley isabella connected unexceptionably
# Model Output:  felt honest pride complacency alliance present future proprietor could fairly warrant viewed respectable size style building suitable becoming characteristic situation low sheltered ample gardens stretching meadows washed stream abbey old neglect prospect scarcely sight abundance timber rows avenues neither fashion extravagance rooted house larger hartfield totally unlike covering good deal round rambling irregular many comfortable one two handsome rooms ought looked emma felt increasing respect residence family true gentility untainted blood understanding faults temper john knightley isabella connected unexceptionably
#
#
# Original sentence:  dear mrs weston
# Mistyped non-word error sentence:  dear fro weston
# Model Output:  dear fro weston
#
#
# Original sentence:  might weeks might days horse useable preparations could ventured melancholy stagnation
# Mistyped non-word error sentence:  might weeks might days horse useable preparations told ventured melancholy stagnation
# Model Output:  might weeks might days horse useable preparation told ventured melancholy stagnation
#
#
# Original sentence:  good send whole way
# Mistyped non-word error sentence:  good send wool way
# Model Output:  good send wool way
#
#
# Original sentence:  children might stay well
# Mistyped non-word error sentence:  children might stay well
# Model Output:  children might stay well
#
#
# Original sentence:  ill ill young lady ever allowed look ill
# Mistyped non-word error sentence:  ill ill young lady ever followed look ill
# Model Output:  ill ill young lady ever followed look ill
#
#
# Original sentence:  oh
# Mistyped non-word error sentence:
# Model Output:
#
#
# Original sentence:  believed foolish alarmed within half minute sending mr perry
# Mistyped non-word error sentence:  believed foolish alarmed within half minute sending mr perry
# Model Output:  believed foolish alarmed within half minute sending mr perry
#
#
# Original sentence:  wonder young man could assurance ask
# Mistyped non-word error sentence:  wonder wound man could assurance ask
# Model Output:  wonder wound man would assurance ask
#
#
# Original sentence:  shall stir
# Mistyped non-word error sentence:  shall stay
# Model Output:  shall stay
#
#
# Original sentence:  emma venture take part poor husband
# Mistyped non-word error sentence:  emma venture state part poor husband
# Model Output:  emma venture state part poor husband
#
#
# Original sentence:  really ashamed always leading way
# Mistyped non-word error sentence:  weakly ashamed always leading way
# Model Output:  weakly ashamed always leading way
#
#
# Original sentence:  least idea weak young man feel sure
# Mistyped non-word error sentence:  least idea weak young man fed sure
# Model Output:  least idea weak young man fed sure
#
#
# Original sentence:  indeed
# Mistyped non-word error sentence:  induced
# Model Output:  induced
#
#
# Original sentence:  seemed like forerunner something absolutely serious wish
# Mistyped non-word error sentence:  seemed lie forerunner something absolutely serious wish
# Model Output:  seemed lie forerunner something absolutely serious wish
#
#
# Original sentence:  wonder speaks coles calls
# Mistyped non-word error sentence:  wonder seats coles calls
# Model Output:  wonder seats coles calls
#
#
# Original sentence:  want puzzle
# Mistyped non-word error sentence:  bank puzzle
# Model Output:  rank puzzle
#
#
# Original sentence:  heard speak acquaintance said emma elegant young woman
# Mistyped non-word error sentence:  heard speak acquaintance said emma elegant wound woman
# Model Output:  heard speak acquaintance said emma elegant wound woman
#
#
# Original sentence:  shall go abroad couple years return shall come wife
# Mistyped non-word error sentence:  shall go abroad could years return shall come wife
# Model Output:  shall go abroad could years return shall come wife
#
#
# Original sentence:  cannot guess parcel holds
# Mistyped non-word error sentence:  cannot fuss parcel holds
# Model Output:  cannot fuss parcel colds
#
#
# Original sentence:  henry fine boy john like mama
# Mistyped non-word error sentence:  henry fine boy john lie mama
# Model Output:  henry fine boy john lie made
#
#
# Original sentence:  plan arisen sacrifice trusted dearest emma would find respect objectionable received hartfield long father happiness words life required hartfield continue home likewise
# Mistyped non-word error sentence:  plan arisen sacrifice rested dearest emma would find respect objectionable received hartfield long father happiness words life required hartfield continue home likewise
# Model Output:  plan arisen sacrifice rested dearest emma would find respect objectionable received hartfield long father happiness words life required hartfield continue home likewise
#
#
# Original sentence:  air probability sometimes runs dream
# Mistyped non-word error sentence:  air probability sometimes brunt dream
# Model Output:  air probability sometimes brunt dream
#
#
# Original sentence:  one think nothing else
# Mistyped non-word error sentence:  fond think nothing else
# Model Output:  fond think nothing else
#
#
# Original sentence:  mother often talks good nature
# Mistyped non-word error sentence:  mother softer talks good nature
# Model Output:  mother softer talks good nature
#
#
# Original sentence:  soon appeared london place
# Mistyped non-word error sentence:  soon appeared london pale
# Model Output:  soon appeared london pace
#
#
# Original sentence:  uncle good encroach must still add long letter
# Mistyped non-word error sentence:  uncle fond encroach must still add long letter
# Model Output:  uncle fond encroach must still add long letter
#
#
# Original sentence:
# Mistyped non-word error sentence:
# Model Output:
#
#
# Original sentence:  cannot imagine suddenly come
# Mistyped non-word error sentence:  cannot image suddenly come
# Model Output:  cannot image sudden come
#
#
# Original sentence:  would ask pleasure company mr knightley slow walker pace would tedious besides another long walk donwell abbey
# Mistyped non-word error sentence:  would ask pleasure company mr knightley row walker pace would tedious besides another long walk donwell abbey
# Model Output:  would ask pleasure compare mr knightley row walker pace would tedious besides another long walk donwell abbey
#
#
# Original sentence:  upon word air great probability
# Mistyped non-word error sentence:  upon word gain great probability
# Model Output:  upon word gain great probability
#
#
# Original sentence:  tell aunt little emma ought set better example renewing old grievances wrong
# Mistyped non-word error sentence:  told aunt little emma ought set better example renewing old grievances wrong
# Model Output:  told aunt little emma ought set better example renewing old grievances wrong
#
#
# Original sentence:  two want
# Mistyped non-word error sentence:  two bank
# Model Output:  two rank
#
#
# Original sentence:  know could imagine confess seldom seen face figure pleasing
# Mistyped non-word error sentence:  know could imagine confess seldom seen face figure pleasing
# Model Output:  know could imagine confess seldom seen face figure pleasing
#
#
# Original sentence:  handsomest man ever man every body looks quite like mr knightley
# Mistyped non-word error sentence:  handsomest man ever man every boy looks quite like mr knightley
# Model Output:  handsome man ever man every boy looks quite like mr knightley
#
#
# Original sentence:  strange rumour highbury little perrys seen slice mrs weston wedding cake hands mr woodhouse would never believe
# Mistyped non-word error sentence:  strange rumour highbury little perrys seen slice mrs weston wedding cake hands mr woodhouse told never believe
# Model Output:  strange rumour highbury little perry seen slice mrs weston wedding cake hands mr woodhouse told never believe
#
#
# Original sentence:  knightley never seen life call knightley discover gentleman
# Mistyped non-word error sentence:  knightleys never seen life call knightleys discover gentleman
# Model Output:  knightley never seen life call knightley discover gentleman
#
#
# Original sentence:  chapter xv
# Mistyped non-word error sentence:  chapter
# Model Output:  chapter
#
#
# Original sentence:  see headache
# Mistyped non-word error sentence:  see headache
# Model Output:  see headaches
#
#
# Original sentence:  mr woodhouse told
# Mistyped non-word error sentence:  mr woodhouses told
# Model Output:  mr woodhouse told
#
#
# Original sentence:  alarming change emma thinking one morning must bring great deal agitate grieve mr knightley came distressing thoughts put
# Mistyped non-word error sentence:  alarming change emma thinking one morning must bring dream deal agitate grieve mr knightley came distressing thoughts put
# Model Output:  alarming change emma thinking one morning must bring dream deal agitate grieve mr knightley came distressing thoughts put
#
#
# Original sentence:  hurried guests prepare father appearance beyond reach mr weston hint
# Mistyped non-word error sentence:  hurried guests prepare father appearance beyond reach  weston hint
# Model Output:  harriet guests prepare father appearance beyond reach  weston hint
#
#
# Original sentence:  emma quite loss
# Mistyped non-word error sentence:  emma quite loud
# Model Output:  emma quite lord
#
#
# Original sentence:  see consequence keeping company say
# Mistyped non-word error sentence:  see consequence keeping company say
# Model Output:  see consequence keeping company say
#
#
# Original sentence:  mother delighted three months us least
# Mistyped non-word error sentence:  mother delighted three months  least
# Model Output:  mother delighted three months  last
#
#
# Original sentence:  like mr elton papa must look wife
# Mistyped non-word error sentence:  like mr elton papa amuse look wife
# Model Output:  like mr elton papa amuse look wife
#
#
# Original sentence:  good natured woman
# Mistyped non-word error sentence:  good natured worn
# Model Output:  good natured work
#
#
# Original sentence:  materially changed since talked subject
# Mistyped non-word error sentence:  materially changed since talker subject
# Model Output:  materially changed since talked subject
#
#
# Original sentence:  jane declares well soon within door well
# Mistyped non-word error sentence:  jane declares well soon wishing door well
# Model Output:  jane declares well soon wishing door well
#
#
# Original sentence:  mr knightley delightful party last night extremely pleasant ever see dancing delightful miss woodhouse mr frank churchill never saw thing equal
# Mistyped non-word error sentence:  mr knightley delightful party last night extremely pleasant river see dancing delightful miss woodhouse mr frank churchill nriver saw thing equal
# Model Output:  mr knightley delightful party last night extremely pleasant river see dancing delightful miss woodhouse mr frank churchill nriver saw thing equal
#
#
# Original sentence:  backgammon table placed visitor immediately afterwards walked made unnecessary
# Mistyped non-word error sentence:  backgammon table placed visitor immediately afterwards wasted made unnecessary
# Model Output:  backgammon table placed visitor immediately afterwards wasted made unnecessary
#
#
# Original sentence:  really time past least three months cared nothing
# Mistyped non-word error sentence:  really time past dealt three months cared nothing
# Model Output:  really time past dealt three months cared nothing
#
#
# Original sentence:  important recordable events productive meetings usually
# Mistyped non-word error sentence:  important recordable events productive meetings usually
# Model Output:  important recordable events productive meetings equally
#
#
# Original sentence:  inclines one less bear fair pretence family blood
# Mistyped non-word error sentence:  inclines one begs bear fair pretence family blood
# Model Output:  inclines one begs bear fair pretence family bloom
#
#
# Original sentence:  fortunate forget precise words one business remember
# Mistyped non-word error sentence:  fortunate forget precisely words one business remember
# Model Output:  fortunate forget precisely words one business remember
#
#
# Original sentence:  feared must decided involvement
# Mistyped non-word error sentence:  feared must decided involvement
# Model Output:  heard must decided involvement
#
#
# Original sentence:  depend upon coming much know parties well
# Mistyped non-word error sentence:  depend upon coming much know parties welch
# Model Output:  depend upon coming much know parties wretch
#
#
# Original sentence:  sorry
# Mistyped non-word error sentence:  carry
# Model Output:  marry
#
#
# Original sentence:  charade obliging leave us thank sight
# Mistyped non-word error sentence:  charade obliging leave us thank insight
# Model Output:  charade obliging leave us think insight
#
#
# Original sentence:  private resolution communicated least communicated way carry conviction till yesterday know said dark plans
# Mistyped non-word error sentence:  private resolution communicated least communicated way carry conviction till yesterday know said dark plans
# Model Output:  private resolution communicated least communicated way carry conviction till yesterday know said dark plans
#
#
# Original sentence:  tenderest spirit gallantry towards us must let read
# Mistyped non-word error sentence:  tenderest spirit gallantry towards us must let read
# Model Output:  tenderness spirit gallantry towards us must let read
#
#
# Original sentence:  nothing compared
# Mistyped non-word error sentence:  nothing compared
# Model Output:  nothing compared
#
#
# Original sentence:  never known pleasure triumph lucky guess pity thought cleverer depend upon lucky guess never merely luck
# Mistyped non-word error sentence:  never known pleasures triumph lucky guess pity thought cleverer depend upon lucky guess never merely luck
# Model Output:  never known pleasures triumph lucky guess pity thought cleverer depend upon lucky guess never merely luck
#
#
# Original sentence:  every respect saw approved confirmed kind designs
# Mistyped non-word error sentence:  every respect saw approved confirmed kind reigns
# Model Output:  every respect saw approved confirmed kind reign
#
#
# Original sentence:  dare let mother know little eats say one thing say another passes
# Mistyped non-word error sentence:  dare let mother know little eats say one string say another passes
# Model Output:  dare let mother know little eats say one string say another passed
#
#
# Original sentence:  grieved find point telling called mrs goddard door last thing returned dress told miss smith better means better rather worse
# Mistyped non-word error sentence:  grieved find point telling called mrs goddard door last thing returned dress told miss smith better means better rather worse
# Model Output:  grieved find point telling called mrs goddard door last thing returned dress told miss smith better means better father worse
#
#
# Original sentence:  child good fortune
# Mistyped non-word error sentence:  child fond fortune
# Model Output:  child fond fortune
#
#
# Original sentence:  mr mrs weston think strongly persuaded though meaning induced body else give situation believed replete good could change great curiosity see decided intention finding pleasant liked certain degree sort pleasure idea coupled friends imaginations
# Mistyped non-word error sentence:  mr mrs weston think strongly persuaded though meaning induced body else give situation believed replete good could change great curiosity see decided intention finding pleasant liked certain degree sort pleasure idea coupled friends imaginations
# Model Output:  mr mrs weston think strongly persuaded though meaning induced body else give situation believed replete good would change great curiosity see decided intention finding pleasant liked certain degree sort pleasure idea coupled friends imaginations
#
#
# Original sentence:  could satisfied without promise would give influence procuring
# Mistyped non-word error sentence:  could satisfies without promise would give influence procuring
# Model Output:  could satisfied without promise would give influence procuring
#
#
# Original sentence:  cannot call george
# Mistyped non-word error sentence:  carrot call george
# Model Output:  carry call george
#
#
# Original sentence:  woman ever excused thinking situation like jane fairfax one may almost say world world law
# Mistyped non-word error sentence:  woman ever excused thinking situation lie jane fairfax one may almost say world world law
# Model Output:  woman ever excused thinking situation lie jane fairfax one may almost say would would law
#
#
# Original sentence:  want likeness fortunate attitude meant throw little improvement figure give little height considerably elegance great confidence every way pretty drawing last filling destined place credit standing memorial beauty one skill friendship many agreeable associations mr elton promising attachment likely add
# Mistyped non-word error sentence:  want likeness fortunate attitude meant throw liable improvement figure give liable height considerably elegance great confidence every way pretty drawing last filling destined place credit standing memorial beauty one skill friendship many agreeable associations mr elton promising attachment likely add
# Model Output:  want likeness fortunate attitude meant throw liable improvement figure give liable height considerably elegance great confidence every way pretty drawing last filling destined place credit standing memorial beauty one still friendship many agreeable associations mr elton promising attachment likely add
#
#
# Original sentence:  could never get acquainted know coldness reserve apparent indifference whether pleased aunt eternal talker made fuss every body always imagined intimate ages every body supposed must fond
# Mistyped non-word error sentence:  could never get acquainted know coldness reserve apparent indifference whether pleased aunt eternal talker made fuss severe body always imagined intimate ages severe body supposed must fond
# ...
# Model Output:  sorry sir assure children great deal good
#
#
# Original sentence:  sit write fine flourishing letter full professions falsehoods persuade hit upon best method world preserving peace home preventing father right complain
# Mistyped non-word error sentence:  sit write fine flourishing letter full professions falsehoods persuade hit upon begs method world preserving peace home preventing father right complain
# Model Output:  set write fine flourishing letter full professions falsehoods persuade hit upon begs method world preserving peace home preventing father right complain
#
#
# Original sentence:  every thing take natural course however neither impelled assisted
# Mistyped non-word error sentence:  every string take natural course however neither impelled assisted
# Model Output:  every string take natural course however neither impelled assisted
#
#
# Original sentence:  sure much surprized first heard going married
# Mistyped non-word error sentence:  sure much surprized fires heard going married
# Model Output:  sure much surprized fires heard going married
#
#
# Original sentence:  wife persuading care health happen doubt time little premature
# Mistyped non-word error sentence:  wife persuading care health happen doubt lie little premature
# Model Output:  wife persuading care health happen doubt lie little creature
#
#
# Original sentence:  serious miss woodhouse whatever penetrating eyes may fancy sick england would leave morrow could
# Mistyped non-word error sentence:  serious miss woodhouse whatever penetrating eyes may fancy sick england would leave morrow could
# Model Output:  seriously miss woodhouse whatever penetrating eyes may fancy sick england would leave morrow could
#
#
# Original sentence:  emma thought least
# Mistyped non-word error sentence:  elms thought least
# Model Output:  else thought least
#
#
# Original sentence:  oh
# Mistyped non-word error sentence:
# Model Output:
#
#
# Original sentence:  think indeed said john knightley pleasantly mr weston little claim
# Mistyped non-word error sentence:  think indeed said john knightley pleasantly  weston little claim
# Model Output:  think indeed said john knightley pleasantly  weston little claims
#
#
# Original sentence:  shall certainly leisure
# Mistyped non-word error sentence:  ball certainly leisure
# Model Output:  ball certainly leisure
#
#
# Original sentence:  strong notion comes
# Mistyped non-word error sentence:  strong notion comes
# Model Output:  strong notion come
#
#
# Original sentence:  say chose walk six yards door pleasure meeting henry john seen drops could count long
# Mistyped non-word error sentence:  say chose walk six yards door pleasure meeting henry john seen drops could brunt long
# Model Output:  say chose walk six yards door pleasure meeting henry john seen drops could brunt long
#
#
# Original sentence:  supposed must say entitled clemency hard case obliged still lower opinion
# Mistyped non-word error sentence:  supposed amuse say entitled clemency hard case obliged still lower opinion
# Model Output:  supposed amuse say entitled clemency hard case obliged still lower opinion
#
#
# Original sentence:  complete every recommendation _almost_ told loved
# Mistyped non-word error sentence:  completest every recommendation _almost_ told loved
# Model Output:  completed every recommendation _almost_ told loved
#
#
# Original sentence:  must morning
# Mistyped non-word error sentence:  must turning
# Model Output:  must turning
#
#
# Original sentence:  elton wonder curiosity see
# Mistyped non-word error sentence:  elton wonder curiosity see
# Model Output:  elton wonder curiosity see
#
#
# Original sentence:  jane actually point going governess
# Mistyped non-word error sentence:  jane actually pointed going governess
# Model Output:  jane actually pointed going governess
#
#
# Original sentence:  mr knightley harriet arrived absence sitting father mr
# Mistyped non-word error sentence:  mr knightleys harriet arrived absence sitting father mr
# Model Output:  mr knightley harriet arrived absence sitting father mr
#
#
# Original sentence:  wish distinguishing far civility permitted evident though could often proceed beyond look
# Mistyped non-word error sentence:  wish distinguishing far civilly permitted evident though could often proceed beyond look
# Model Output:  wish distinguishing far civilly permitted evident though could often proceed beyond look
#
#
# Original sentence:  mimic
# Mistyped non-word error sentence:  music
# Model Output:  music
#
#
# Original sentence:  contrivances modern days indeed rendered gentleman carriage perfectly complete
# Mistyped non-word error sentence:  contrivances modern days indeed wondered gentleman carriage perfectly complete
# Model Output:  contrivances modern days indeed wondered gentleman carriage perfectly complete
#
#
# Original sentence:  pray
# Mistyped non-word error sentence:  perry
# Model Output:  perry
#
#
# Original sentence:  extreme sweetness temper must hurt
# Mistyped non-word error sentence:  extreme sweetness temper must put
# Model Output:  extreme sweetness temper must put
#
#
# Original sentence:  would bad thing much love proper object
# Mistyped non-word error sentence:  would bad thing much love proved object
# Model Output:  would bad thing much love proved object
#
#
# Original sentence:  one shall never change however
# Mistyped non-word error sentence:  one ball never change however
# Model Output:  one ball never change however
#
#
# Original sentence:  hesitated moment replied ask
# Mistyped non-word error sentence:  hesitated moment replied bank
# Model Output:  hesitated moment replied rank
#
#
# Original sentence:  oh
# Mistyped non-word error sentence:
# Model Output:
#
#
# Original sentence:  totally different feelings emma take back house brought daring hope little respite suffering exquisite flutter happiness happiness moreover believed must still greater flutter passed away
# Mistyped non-word error sentence:  totally different feelings emma take back house brought daring hope little respite suffering exquisite flutter happiness happiness moreover believed must still greater flutter passed war
# Model Output:  totally different feelings emma taken back house brought daring hope little respite suffering exquisite flutter happiness happiness moreover believed must still greater flutter passed war
#
#
# Original sentence:  cannot believe power coming made point
# Mistyped non-word error sentence:  cannot believe poor coming made point
# Model Output:  cannot believe poor coming made point
#
#
# Original sentence:  understood ways could allow ignorance temptations romantic expectations extraordinary virtue education done little entered troubles ready sympathy always gave assistance much intelligence good
# Mistyped non-word error sentence:  understood ways could allow ignorance temptations romantic expectations extraordinary virtue education done little entree troubles ready sympathy always gave assistance much intelligence good
# Model Output:  understand ways could allow ignorance temptations romantic expectations extraordinary virtue education done little entree troubles ready sympathy always gave assistance much intelligence good
#
#
# Original sentence:  affection man mr elton would great distinction never could deserved nobody partial kind friend miss woodhouse would thought possible
# Mistyped non-word error sentence:  affection man mr elton would great distinction never could deserved nobody partial kind friend miss woodhouse would thought possible
# Model Output:  affection man mr elton would great distinction never could deserved nobody partial mind friend miss woodhouse would thought possible
#
#
# Original sentence:  one cannot resolve upon hurry
# Mistyped non-word error sentence:  fond cannot resolve upon hurry
# Model Output:  fond cannot resolve upon hurry
#
#
# Original sentence:  mentioned mrs dixon felt much probable tribute warm female friendship
# Mistyped non-word error sentence:  mentioned mrs dixon felt vouch probable tribute warm female friendship
# Model Output:  mentioned mrs dixon felt vouch probable tribute warm female friendship
#
#
# Original sentence:  dear clever could really meant
# Mistyped non-word error sentence:  dream clever could really meant
# Model Output:  dream clever would really meant
#
#
# Original sentence:  ladies never look ill seriously miss fairfax naturally pale almost always give appearance ill health deplorable want complexion
# Mistyped non-word error sentence:  ladies never look ill seriously remiss fairfax naturally pale almost always give appearance ill health deplorable want complexion
# Model Output:  ladies ever look ill seriously remiss fairfax naturally pale almost always give appearance ill health deplorable want complexion
#
#
# Original sentence:  occasion press matter farther
# Mistyped non-word error sentence:  occasional press matter farther
# Model Output:  occasional press matter father
#
#
# Original sentence:  certainly get better better
# Mistyped non-word error sentence:  certainly led better better
# Model Output:  certainly led better better
#
#
# Original sentence:  give carte blanche lady patroness know
# Mistyped non-word error sentence:  give carry blanche lady patroness know
# Model Output:  give carry blanche lady patroness know
#
#
# Original sentence:  poor old john great regard clerk poor father twenty seven years poor old man bed ridden poorly rheumatic gout joints must go see day jane sure gets
# Mistyped non-word error sentence:  poor old john great regard clerk poor father twenty saves years poor old man bed ridden poorly rheumatic gout joints must go see day jane sure gets
# Model Output:  poor old john great regard clerk poor father twenty saves years poor old man bed ridden poorly rheumatic gout joints must go see day jane sure gets
#
#
# Original sentence:  miss woodhouse quite concerned sure hit foot
# Mistyped non-word error sentence:  miss woodhouse quite concerned sun hit foot
# Model Output:  miss woodhouse quite concerned sun hit foot
#
#
# Original sentence:  poor little anna weston spoiled greatest humanity much done except falling love thirteen
# Mistyped non-word error sentence:  poor little anna weston spoiled greatest humanity much done except darling love thirteen
# Model Output:  poor little anna weston spoiled greatest humanity much none except darling love thirteen
#
#
# Original sentence:  sitting appeared companionably home till usual hour exercise desired chuse walk immediately fixed highbury doubt pleasant walks every direction left always chuse
# Mistyped non-word error sentence:  sitting appeared companionably home till usual hour exercise desired chuse walk immediate fixed highbury doubt pleasant walks every direction left always chuse
# Model Output:  sitting appeared companionably come till usual hour exercise desired chuse walk immediate fixed highbury doubt pleasant walks every direction left always chuse
#
#
# Original sentence:  think come shall think know enscombe
# Mistyped non-word error sentence:  think score shall think know enscombe
# Model Output:  think score shall think know enscombe
#
#
# Original sentence:  never seen frank churchill silent stupid
# Mistyped non-word error sentence:  never sun frank churchill silent stupid
# Model Output:  never sun frank churchill sent stupid
#
#
# Original sentence:  mr knightley hard work upon lower buttons thick leather gaiters either exertion getting together cause brought colour face answered
# Mistyped non-word error sentence:  mr knightley hard work upon lower buttons thick leather gaiters either exertion getting together cause brought cooler face answered
# Model Output:  mr knightley hard work upon lower buttons thick leather gaiters either exertion getting together cause brought cooler face answered
#
#
# Original sentence:  thoroughly understand telling brother cried emma friend mr graham intending bailiff scotland look new estate
# Mistyped non-word error sentence:  thoroughly understand telling brother cried emma friend mr graham intending bailiff scotland look new estate
# Model Output:  thoroughly understands telling brother cried emma friend mr graham intending bailiff scotland look new estate
#
#
# Original sentence:  met letters way morning seeing son hand presumed open though directed mrs weston
# Mistyped non-word error sentence:  led letters way morning seeing son hand presumed open though directed mrs weston
# Model Output:  let letters way morning seeing son hand presumed open though directed mrs weston
#
#
# Original sentence:  never quite well since time daughter marriage till completely recovered usual strength must forbid engaging duties far compatible weakened frame varying spirits seemed favourable circumstances require something human perfection body mind discharged tolerable comfort
# Mistyped non-word error sentence:  river quite well since time daughter marriage till completely recovered usual strength must forbid engaging duties far compatible weakened frame varying spirits seemed favourable circumstances require something human perfection body mind discharged tolerable comfort
# Model Output:  rivet quite well since time daughter marriage till completely recovered usual strength must forbid engaging duties far compatible weakened frame varying spirits seemed favourable circumstances require something human perfection body mind discharged tolerable comfort
#
#
# Original sentence:  exceedingly sorry well mistake ends
# Mistyped non-word error sentence:  exceedingly sorry well mistake mend
# Model Output:  exceedingly sorry well mistake mind
#
#
# Original sentence:  weston may grow cross wantonness comfort son may plague
# Mistyped non-word error sentence:  weston may grow cross wantonness comfort son may plague
# Model Output:  weston may grow cross wantonness comfort son may place
#
#
# Original sentence:  advise custard
# Mistyped non-word error sentence:  admire custard
# Model Output:  admire custard
#
#
# Original sentence:  would affect frank among earliest thoughts
# Mistyped non-word error sentence:  would affect bank among earliest thoughts
# Model Output:  would affect bank among earliest thought
#
#
# Original sentence:  great commonly thankful delight towards mrs elton emma guessed little show resentment towards jane vicarage quarter graciously overcome whispers indeed placed beyond guess mrs elton speaking louder said
# Mistyped non-word error sentence:  great commonly thankful delight towards mrs elton emma blessed little show resentment towards jane vicarage quarter graciously overcome whispers indeed placed beyond guess mrs elton speaking louder said
# Model Output:  great commonly thankful delight towards mrs elton emma pleased little show resentment towards jane vicarage quarter graciously overcome whispers indeed placed beyond guess mrs elton speaking louder said
#
#
# Original sentence:  mrs dixon must much disappointed
# Mistyped non-word error sentence:  mrs dixon must vouch disappointed
# Model Output:  mr dixon must vouch disappointed
#
#
# Original sentence:  considering particular friendship mrs dixon could hardly expected excused accompanying colonel mrs
# Mistyped non-word error sentence:  considering particular friendship mrs dixon could hardly unexpected excused accompanying colonel mrs
# Model Output:  considering particular friendship mrs dixon could hardly expected excused accompanying colonel mrs
#
#
# Original sentence:  every thing said done many weeks past sole view marking adoration
# Mistyped non-word error sentence:  every thing said done many weak past sole view marking adoration
# Model Output:  every thing said done many weak past sole view making adoration
#
#
# Original sentence:  thank
# Mistyped non-word error sentence:  bank
# Model Output:  rank
#
#
# Original sentence:  really well observed nothing course seems new idea think made discoveries
# Mistyped non-word error sentence:  really well observer nothing course seems new idea think made discoveries
# Model Output:  really well observe nothing course seems new idea think made discoveries
#
#
# Original sentence:  know tempers manage
# Mistyped non-word error sentence:  know trampers manage
# Model Output:  know trampers manage
#
#
# Accuracy for Real World is: 0.15025906735751296
